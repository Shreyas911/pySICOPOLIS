# %%
# HPC
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt

# Paths and stuff
import os
import sys

sys.path.append('/home/shreyas/pySICOPOLIS/src')
from pySICOPOLIS import *

# %%
modelPath = '/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/'
dataPath = '/scratch2/shreyas/GrIS_paleo_data/'

ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp0006.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp0007.nc')

ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp_ser.nc')
ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp_ser.nc')
ds_ser_grl40_bm5_spinup02_smooth_100a = xr.open_dataset(modelPath + 'grl40_bm5_spinup02_smooth_100a/grl40_bm5_spinup02_smooth_100a_ser.nc')

ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp0006.nc')
ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp0007.nc')
ds_grl40_bm5_spinup02_smooth_100a = xr.open_dataset(modelPath + 'grl40_bm5_spinup02_smooth_100a/grl40_bm5_spinup02_smooth_100a0001.nc')

ds_bm5_40kms = xr.open_dataset(dataPath + 'bm5_data_40kms.nc')
ds_surfvel_data_40km = xr.open_dataset(dataPath + 'surfvel_data_40kms.nc')

# %%
n_rows, n_cols = 3, 2
aspect_ratio = len(ds_grl40_bm5_spinup02_smooth_100a['x'])/len(ds_grl40_bm5_spinup02_smooth_100a['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.8)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

for axis in ax.flatten():
    axis.set_box_aspect(1/aspect_ratio)
    
fancyPlotter.plot_normal(ds_bm5_40kms['xModel'], 
                         ds_bm5_40kms['yModel'], 
                         ds_bm5_40kms['H'],
                         cmap = 'jet', nbins = 20, vmin = 0, vmax = 3500, fig = fig, ax = ax[0, 0])

fancyPlotter.plot_normal(ds_grl40_bm5_spinup02_smooth_100a['x']/1000.0, 
                         ds_grl40_bm5_spinup02_smooth_100a['y']/1000.0, 
                         ds_grl40_bm5_spinup02_smooth_100a['H'],
                         cmap = 'jet', nbins = 20, vmin = 0, vmax = 3500, fig = fig, ax = ax[0, 1])

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['H'],
                         cmap = 'jet', nbins = 20, vmin = 0, vmax = 3500, fig = fig, ax = ax[1, 0])

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['H'],
                         cmap = 'jet', nbins = 20, vmin = 0, vmax = 3500, fig = fig, ax = ax[1, 1])

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['H'],
                         cmap = 'jet', nbins = 20, vmin = 0, vmax = 3500, fig = fig, ax = ax[2, 0])

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp['H'],
                         cmap = 'jet', nbins = 20, vmin = 0, vmax = 3500, fig = fig, ax = ax[2, 1])

plt.tight_layout()

# %%
n_rows, n_cols = 3, 2
aspect_ratio = len(ds_grl40_bm5_spinup02_smooth_100a['x'])/len(ds_grl40_bm5_spinup02_smooth_100a['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+1.0)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

for axis in ax.flatten():
    axis.set_box_aspect(1/aspect_ratio)
    
fancyPlotter.plot_log(ds_surfvel_data_40km['x'], 
                      ds_surfvel_data_40km['y'], 
                      ds_surfvel_data_40km['vs'],
                      cmap = 'RdBu_r', nbins = None, bin_edges = [0, 1, 2, 3], fig = fig, ax = ax[0, 0])

fancyPlotter.plot_log(ds_grl40_bm5_spinup02_smooth_100a['x']/1000.0, 
                      ds_grl40_bm5_spinup02_smooth_100a['y']/1000.0, 
                      ds_grl40_bm5_spinup02_smooth_100a['vh_s'],
                      cmap = 'RdBu_r', nbins = None, bin_edges = [0, 1, 2, 3], fig = fig, ax = ax[0, 1])

fancyPlotter.plot_log(ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['x']/1000.0, 
                      ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['y']/1000.0, 
                      ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['vh_s'],
                      cmap = 'RdBu_r', nbins = None, bin_edges = [0, 1, 2, 3], fig = fig, ax = ax[1, 0])

fancyPlotter.plot_log(ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['x']/1000.0, 
                      ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['y']/1000.0, 
                      ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['vh_s'],
                      cmap = 'RdBu_r', nbins = None, bin_edges = [0, 1, 2, 3], fig = fig, ax = ax[1, 1])

fancyPlotter.plot_log(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['x']/1000.0, 
                      ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['y']/1000.0, 
                      ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['vh_s'],
                      cmap = 'RdBu_r', nbins = None, bin_edges = [0, 1, 2, 3], fig = fig, ax = ax[2, 0])

fancyPlotter.plot_log(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp['x']/1000.0, 
                      ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp['y']/1000.0, 
                      ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp['vh_s'],
                      cmap = 'RdBu_r', nbins = None, bin_edges = [0, 1, 2, 3], fig = fig, ax = ax[2, 1])

plt.tight_layout()
# Out:
# /scratch2/shreyas/mambaforge/envs/py310_LRP/lib/python3.10/site-packages/xarray/core/computation.py:818: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# /scratch2/shreyas/mambaforge/envs/py310_LRP/lib/python3.10/site-packages/xarray/core/computation.py:818: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# /scratch2/shreyas/mambaforge/envs/py310_LRP/lib/python3.10/site-packages/xarray/core/computation.py:818: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# /scratch2/shreyas/mambaforge/envs/py310_LRP/lib/python3.10/site-packages/xarray/core/computation.py:818: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# /scratch2/shreyas/mambaforge/envs/py310_LRP/lib/python3.10/site-packages/xarray/core/computation.py:818: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)
# ...

# %%
ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['vh_s'].data[35,20], \
ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['vh_s'].data[26,29], \
ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['vh_s'].data[22,25]
# Out:
# (25.75993, 489.28918, 226.86458)

# %%
ds_surfvel_data_40km['vs'].data[35,20], \
ds_surfvel_data_40km['vs'].data[26,29], \
ds_surfvel_data_40km['vs'].data[22,25]
# Out:
# (26.830793, 109.77768, 785.7048)

# %%
costs = 0.5*(ds_surfvel_data_40km['vs'].data-ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['vh_s'].data)**2
cost = np.sum(costs)

# %%
np.max(costs), cost
# Out:
# (214771.56, 4200313.0)

# %%
np.sum(np.sort(costs.flatten())[-1:])/cost*100, \
np.sum(np.sort(costs.flatten())[-3:])/cost*100, \
np.sum(np.sort(costs.flatten())[-10:])/cost*100, \
np.sum(np.sort(costs.flatten())[-20:])/cost*100, \
np.sum(np.sort(costs.flatten())[-50:])/cost*100, \
np.sum(np.sort(costs.flatten())[-100:])/cost*100, \
np.sum(np.sort(costs.flatten())[-500:])/cost*100
# Out:
# (5.113227665424347,
#  13.003496825695038,
#  29.386162757873535,
#  43.907418847084045,
#  67.06812381744385,
#  84.28433537483215,
#  99.6634304523468)

# %%
n_rows, n_cols = 1, 1
aspect_ratio = len(ds_grl40_bm5_spinup02_smooth_100a['x'])/len(ds_grl40_bm5_spinup02_smooth_100a['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.1)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

ax.set_box_aspect(1/aspect_ratio)

fancyPlotter.plot_log(ds_surfvel_data_40km['x'], 
                      ds_surfvel_data_40km['y'], 
                      costs,
                      cmap = 'RdBu_r', nbins = 3, fig = fig, ax = ax)
# Out:
# /home/shreyas/pySICOPOLIS/src/pySICOPOLIS/utils/visualization/plotting.py:124: RuntimeWarning: divide by zero encountered in log10
#   log = np.log10(np.abs(data))

# %%
n_rows, n_cols = 1, 1
aspect_ratio = len(ds_grl40_bm5_spinup02_smooth_100a['x'])/len(ds_grl40_bm5_spinup02_smooth_100a['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.1)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

ax.set_box_aspect(1/aspect_ratio)

fancyPlotter.plot_normal(ds_surfvel_data_40km['x'], 
                         ds_surfvel_data_40km['y'], 
                         costs,
                         cmap = 'RdBu_r', nbins = 3, fig = fig, ax = ax)
