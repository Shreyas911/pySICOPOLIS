# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# Paths and stuff
import os
import sys

sys.path.append('/home/shreyas/pySICOPOLIS/src')
from pySICOPOLIS import *

# %%
ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init
# Out:
# <xarray.Dataset> Size: 11MB
# Dimensions:                  (x: 43, y: 73, zeta_c: 81, zeta_t: 3, zeta_r: 41)
# Coordinates:
#   * x                        (x) float64 344B -7.2e+05 -6.8e+05 ... 9.6e+05
#   * y                        (y) float64 584B -3.45e+06 -3.41e+06 ... -5.7e+05
# Dimensions without coordinates: zeta_c, zeta_t, zeta_r
# Data variables: (12/126)
#     mapping                  int8 1B ...
#     year2sec                 float64 8B ...
#     time                     float64 8B ...
#     delta_ts                 float64 8B ...
#     z_sl_mean                float64 8B ...
#     V_tot                    float64 8B ...
#     ...                       ...
#     enh_c                    (zeta_c, y, x) float32 1MB ...
#     enh_t                    (zeta_t, y, x) float32 38kB ...
#     strain_heating_c         (zeta_c, y, x) float32 1MB ...
#     strain_heating_t         (zeta_t, y, x) float32 38kB ...
#     age_c                    (zeta_c, y, x) float32 1MB ...
# ...

# %%
ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka0005.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka0006.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka0009.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_final = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp0006.nc')

ds_adj_AC_BM5_ZLC_m21ka_more = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m21ka_pkp_more.nc')
ds_adj_AC_BM5_ZLC_m11ka_more = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m11ka_pkp_more.nc')

ds_adj_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp.nc')
ds_adj_BM5_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_BM5_m21ka_pkp.nc')
ds_adj_ZSC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZSC_m21ka_pkp.nc')
ds_adj_ZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZLC_m21ka_pkp.nc')
ds_adj_AC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_m21ka_pkp.nc')
ds_adj_FBM5_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FBM5_m21ka_pkp.nc')
ds_adj_FZSC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZSC_m21ka_pkp.nc')
ds_adj_FZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZLC_m21ka_pkp.nc')
ds_adj_FAC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FAC_m21ka_pkp.nc')
ds_adj_SVC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_SVC_m21ka_pkp.nc')
ds_adj_FSVC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FSVC_m21ka_pkp.nc')
ds_adj_SVC_nudged_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_SVC_m21ka_pkp.nc')
ds_adj_FSVC_nudged_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_FSVC_m21ka_pkp.nc')
ds_adj_AC_BM5_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_m21ka_pkp.nc')
ds_adj_AC_BM5_ZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m21ka_pkp.nc')
ds_adj_AC_ZSC_ZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_ZSC_ZLC_m21ka_pkp.nc')

ds_adj_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp.nc')
ds_adj_BM5_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_BM5_m11ka_pkp.nc')
ds_adj_ZSC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZSC_m11ka_pkp.nc')
ds_adj_ZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZLC_m11ka_pkp.nc')
ds_adj_AC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_m11ka_pkp.nc')
ds_adj_FBM5_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FBM5_m11ka_pkp.nc')
ds_adj_FZSC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZSC_m11ka_pkp.nc')
ds_adj_FZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZLC_m11ka_pkp.nc')
ds_adj_FAC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FAC_m11ka_pkp.nc')
ds_adj_SVC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_SVC_m11ka_pkp.nc')
ds_adj_FSVC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FSVC_m11ka_pkp.nc')
ds_adj_SVC_nudged_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_SVC_m11ka_pkp.nc')
ds_adj_FSVC_nudged_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_FSVC_m11ka_pkp.nc')
ds_adj_AC_BM5_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_m11ka_pkp.nc')
ds_adj_AC_BM5_ZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m11ka_pkp.nc')
ds_adj_AC_ZSC_ZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_ZSC_ZLC_m11ka_pkp.nc')

ds_adj_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp.nc')
ds_adj_BM5_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_BM5_m1ka_pkp.nc')
ds_adj_ZSC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZSC_m1ka_pkp.nc')
ds_adj_ZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZLC_m1ka_pkp.nc')
ds_adj_AC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_m1ka_pkp.nc')
ds_adj_FBM5_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FBM5_m1ka_pkp.nc')
ds_adj_FZSC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZSC_m1ka_pkp.nc')
ds_adj_FZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZLC_m1ka_pkp.nc')
ds_adj_FAC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FAC_m1ka_pkp.nc')
ds_adj_AC_BM5_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_m1ka_pkp.nc')
ds_adj_AC_BM5_ZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m1ka_pkp.nc')
ds_adj_AC_ZSC_ZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_sens/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_ZSC_ZLC_m1ka_pkp.nc')

# %%
def non_dim_sensitivities(ds_init, ds_output_adj):
    non_dim_grads = {}
    fc = ds_output_adj['fc'].data
    print(fc)

    non_dim_grads['c_slide_initb'] = np.sum(np.abs(ds_output_adj['xx_c_slide_initb'].data)) * 0.85 / fc[0]
    # non_dim_grads['delta_tda_constb'] = np.sum(np.abs(ds_output_adj['xx_delta_tda_constb'].data)) * 3.0 / fc[0]
    non_dim_grads['c_dis_dab'] = np.abs(np.sum(ds_output_adj['xx_c_dis_dab'].data)) * 1000.0 / fc[0]
    non_dim_grads['q_geob'] = np.sum(np.abs(ds_output_adj['xx_q_geob'].data * ds_init['q_geo'].data)) / fc[0]
    non_dim_grads['gamma_sb'] = np.sum(np.abs(ds_output_adj['xx_gamma_sb'].data)) * 0.1 / fc[0]
    non_dim_grads['s_statb'] = np.abs(np.sum(ds_output_adj['xx_s_statb'].data)) * 1.0 / fc[0]
    non_dim_grads['beta1b'] = np.abs(np.sum(ds_output_adj['xx_beta1b'].data)) * 1.0 / fc[0]
    non_dim_grads['beta2b'] = np.abs(np.sum(ds_output_adj['xx_beta2b'].data)) * 1.0 / fc[0]
    non_dim_grads['Pmaxb'] = np.abs(np.sum(ds_output_adj['xx_Pmaxb'].data)) * 0.1 / fc[0]
    non_dim_grads['mub'] = np.abs(np.sum(ds_output_adj['xx_mub'].data)) * 1.0 / fc[0]
    # non_dim_grads['RHO_Ab'] = np.abs(np.sum(ds_output_adj['xx_RHO_Ab'].data)) * 1000.0 / fc[0]
    # non_dim_grads['time_lag_asthb'] = np.abs(np.sum(ds_output_adj['xx_time_lag_asthb'].data)) * 1000.0 / fc[0]
    # non_dim_grads['flex_rig_lithb'] = np.sum(np.abs(ds_output_adj['xx_flex_rig_lithb'].data)) * 1.e24 / fc[0]
    non_dim_grads['p_weert'] = np.abs(np.sum(ds_output_adj['xx_p_weertb'].data)) * 1.0 / fc[0]
    non_dim_grads['q_weert'] = np.abs(np.sum(ds_output_adj['xx_q_weertb'].data)) * 1.0 / fc[0]
    non_dim_grads['enh_fact_da_dummy2d_scalar'] = np.abs(np.sum(ds_output_adj['xx_enh_fact_da_dummy2d_scalarb'].data)) * 1.0 / fc[0]
    non_dim_grads['enh_intg_da_dummy2d_scalar'] = np.abs(np.sum(ds_output_adj['xx_enh_intg_da_dummy2d_scalarb'].data)) * 1.0 / fc[0]
    non_dim_grads['n_glen_da_dummy2d_scalar'] = np.abs(np.sum(ds_output_adj['xx_n_glen_da_dummy2d_scalarb'].data)) * 1.0 / fc[0]
    non_dim_grads['zsb'] = np.sum(np.abs(ds_output_adj['xx_zsb'].data)) * 300.0 / fc[0]
    # non_dim_grads['zl0b'] = np.sum(np.abs(ds_output_adj['xx_zl0b'].data * ds_init['zl0'].data)) / fc[0]
    non_dim_grads['zlb'] = np.sum(np.abs(ds_output_adj['xx_zlb'].data)) * 300.0 / fc[0]
    non_dim_grads['zbb'] = np.sum(np.abs(ds_output_adj['xx_zbb'].data)) * 300.0 / fc[0]
    non_dim_grads['temp_cb'] = np.sum(np.abs(ds_output_adj['xx_temp_cb'].data)) * 1.0 / fc[0]
    non_dim_grads['temp_rb'] = np.sum(np.abs(ds_output_adj['xx_temp_rb'].data)) * 1.0 / fc[0]
    non_dim_grads['omega_cb'] = np.sum(np.abs(ds_output_adj['xx_omega_cb'].data)) * 0.01 / fc[0]
    non_dim_grads['age_cb'] = np.sum(np.abs(ds_output_adj['xx_age_cb'].data)) * 10000.0 / fc[0] # * 3.156e+7 # year2sec
    non_dim_grads['delta_tdab'] = np.sum(np.abs(ds_output_adj['xx_delta_tdab'].data[:-1])) * 5.0 / fc[0]

    print(np.sum(np.abs(ds_output_adj['xx_delta_tdab'].data[-1]))/np.sum(np.abs(ds_output_adj['xx_delta_tdab'].data)))
    # non_dim_grads['c_slide_initb'] = np.sum(np.abs(ds_output_adj['xx_c_slide_initb'].data)) * 0.85 / fc[0]
    # non_dim_grads['delta_tda_constb'] = np.sum(np.abs(ds_output_adj['xx_delta_tda_constb'].data)) * 3.74 / fc[0]
    # non_dim_grads['c_dis_dab'] = np.abs(np.sum(ds_output_adj['xx_c_dis_dab'].data)) * 15659.0 / fc[0]
    # non_dim_grads['q_geob'] = np.sum(np.abs(ds_output_adj['xx_q_geob'].data * ds_init['q_geo'].data)) / fc[0]
    # non_dim_grads['gamma_sb'] = np.sum(np.abs(ds_output_adj['xx_gamma_sb'].data)) * 0.070458 / fc[0]
    # non_dim_grads['s_statb'] = np.abs(np.sum(ds_output_adj['xx_s_statb'].data)) * 5.0 / fc[0]
    # non_dim_grads['beta1b'] = np.abs(np.sum(ds_output_adj['xx_beta1b'].data)) * 2.73 / fc[0]
    # non_dim_grads['beta2b'] = np.abs(np.sum(ds_output_adj['xx_beta2b'].data)) * 7.28 / fc[0]
    # non_dim_grads['Pmaxb'] = np.abs(np.sum(ds_output_adj['xx_Pmaxb'].data)) * 0.6 / fc[0]
    # non_dim_grads['mub'] = np.abs(np.sum(ds_output_adj['xx_mub'].data)) * 9.7155 / fc[0]
    # non_dim_grads['RHO_Ab'] = np.abs(np.sum(ds_output_adj['xx_RHO_Ab'].data)) * 3300.0 / fc[0]
    # non_dim_grads['time_lag_asthb'] = np.abs(np.sum(ds_output_adj['xx_time_lag_asthb'].data)) * 3000.0 / fc[0]
    # non_dim_grads['flex_rig_lithb'] = np.sum(np.abs(ds_output_adj['xx_flex_rig_lithb'].data)) * 1.e25 / fc[0]
    # non_dim_grads['p_weert'] = np.abs(np.sum(ds_output_adj['xx_p_weertb'].data)) * 3.0 / fc[0]
    # non_dim_grads['q_weert'] = np.abs(np.sum(ds_output_adj['xx_q_weertb'].data)) * 2.0 / fc[0]
    # non_dim_grads['enh_fact_da_dummy2d_scalar'] = np.abs(np.sum(ds_output_adj['xx_enh_fact_da_dummy2d_scalarb'].data)) * 3.0 / fc[0]
    # non_dim_grads['enh_intg_da_dummy2d_scalar'] = np.abs(np.sum(ds_output_adj['xx_enh_intg_da_dummy2d_scalarb'].data)) * 1.0 / fc[0]
    # non_dim_grads['n_glen_da_dummy2d_scalar'] = np.abs(np.sum(ds_output_adj['xx_n_glen_da_dummy2d_scalarb'].data)) * 3.0 / fc[0]
    # non_dim_grads['zsb'] = np.sum(np.abs(ds_output_adj['xx_zsb'].data * ds_init['zs'].data)) / fc[0]
    # # non_dim_grads['zl0b'] = np.sum(np.abs(ds_output_adj['xx_zl0b'].data * ds_init['zl0'].data)) / fc[0]
    # non_dim_grads['zlb'] = np.sum(np.abs(ds_output_adj['xx_zlb'].data * ds_init['zl'].data)) / fc[0]
    # non_dim_grads['zbb'] = np.sum(np.abs(ds_output_adj['xx_zbb'].data * ds_init['zb'].data)) / fc[0]
    # non_dim_grads['temp_cb'] = np.sum(np.abs(ds_output_adj['xx_temp_cb'].data * ds_init['temp_c'].data)) / fc[0]
    # non_dim_grads['omega_cb'] = np.sum(np.abs(ds_output_adj['xx_omega_cb'].data)) * 0.01 / fc[0]
    # non_dim_grads['age_cb'] = np.sum(np.abs(ds_output_adj['xx_age_cb'].data * ds_init['age_c'].data)) / fc[0] # * 3.156e+7 # year2sec
    # non_dim_grads['delta_tdab'] = np.sum(np.abs(ds_output_adj['xx_delta_tdab'].data)) * 3.74 / fc[0]
    
    # Sum of all calculated non-dimensional sensitivities
    total_sum = sum(non_dim_grads.values())
    
    # Normalize each field to percentage and round to two decimal places
    non_dim_grads_percentage = {key: np.round((value / total_sum) * 100, 2) for key, value in non_dim_grads.items()}
    
    return non_dim_grads_percentage

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_BM5_ZLC_m11ka_more), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_BM5_ZLC_m21ka_more)
# Out:
# [110184.19101195]
# 0.022118082483025086
# [110184.0668274]
# 0.016033733472213874
# ({'c_slide_initb': 9.86,
#   'c_dis_dab': 0.37,
#   'q_geob': 0.55,
#   'gamma_sb': 3.62,
#   's_statb': 1.61,
#   'beta1b': 0.8,
#   'beta2b': 0.62,
#   'Pmaxb': 0.54,
#   'mub': 0.02,
#   'p_weert': 0.28,
#   'q_weert': 1.14,
#   'enh_fact_da_dummy2d_scalar': 0.11,
#   'enh_intg_da_dummy2d_scalar': 1.92,
#   'n_glen_da_dummy2d_scalar': 0.57,
#   'zsb': 1.98,
#   'zlb': 7.88,
#   'zbb': 0.0,
#   'temp_cb': 0.8,
#   'temp_rb': 1.07,
#   'omega_cb': 1.35,
#   'age_cb': 9.78,
#   'delta_tdab': 55.12},
#  {'c_slide_initb': 8.58,
#   'c_dis_dab': 0.31,
#   'q_geob': 2.74,
#   'gamma_sb': 7.2,
#   's_statb': 1.33,
#   'beta1b': 0.66,
#   'beta2b': 0.51,
#   'Pmaxb': 0.45,
#   'mub': 0.01,
#   'p_weert': 0.29,
#   'q_weert': 0.97,
#   'enh_fact_da_dummy2d_scalar': 0.08,
#   'enh_intg_da_dummy2d_scalar': 2.02,
#   'n_glen_da_dummy2d_scalar': 0.47,
#   'zsb': 1.18,
#   'zlb': 2.03,
#   'zbb': 0.0,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_BM5_ZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_BM5_ZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_BM5_ZLC_m21ka)
# Out:
# [110184.06425154]
# [110184.19101195]
# [110184.0668274]
# ({'c_slide_initb': 5.84,
#   'c_dis_dab': 0.22,
#   'q_geob': 0.0,
#   'gamma_sb': 0.71,
#   's_statb': 1.39,
#   'beta1b': 0.56,
#   'beta2b': 0.48,
#   'Pmaxb': 0.41,
#   'mub': 0.0,
#   'p_weert': 0.28,
#   'q_weert': 1.16,
#   'enh_fact_da_dummy2d_scalar': 0.48,
#   'enh_intg_da_dummy2d_scalar': 0.04,
#   'n_glen_da_dummy2d_scalar': 0.31,
#   'zsb': 10.22,
#   'zlb': 23.45,
#   'zbb': 0.0,
#   'temp_cb': 0.84,
#   'temp_rb': 0.65,
#   'omega_cb': 1.36,
#   'age_cb': 42.87,
#   'delta_tdab': 8.74},
#  {'c_slide_initb': 11.88,
#   'c_dis_dab': 0.38,
#   'q_geob': 0.57,
#   'gamma_sb': 3.71,
#   's_statb': 1.65,
#   'beta1b': 0.82,
#   'beta2b': 0.64,
#   'Pmaxb': 0.55,
#   'mub': 0.02,
#   'p_weert': 0.29,
#   'q_weert': 1.17,
#   'enh_fact_da_dummy2d_scalar': 0.12,
#   'enh_intg_da_dummy2d_scalar': 1.96,
#   'n_glen_da_dummy2d_scalar': 0.59,
#   'zsb': 2.03,
#   'zlb': 8.08,
#   'zbb': 0.0,
#   'temp_cb': 0.81,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_SVC_nudged_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_SVC_nudged_m21ka)
# Out:
# [14084.57726687]
# [13307.80596486]
# ({'c_slide_initb': 30.97,
#   'c_dis_dab': 0.25,
#   'q_geob': 0.92,
#   'gamma_sb': 0.45,
#   's_statb': 1.77,
#   'beta1b': 0.59,
#   'beta2b': 0.91,
#   'Pmaxb': 0.41,
#   'mub': 0.05,
#   'p_weert': 6.7,
#   'q_weert': 15.19,
#   'enh_fact_da_dummy2d_scalar': 1.56,
#   'enh_intg_da_dummy2d_scalar': 0.08,
#   'n_glen_da_dummy2d_scalar': 2.85,
#   'zsb': 0.67,
#   'zlb': 0.75,
#   'zbb': 0.0,
#   'temp_cb': 0.8,
#   'temp_rb': 1.18,
#   'omega_cb': 1.39,
#   'age_cb': 0.0,
#   'delta_tdab': 32.5},
#  {'c_slide_initb': 29.08,
#   'c_dis_dab': 0.23,
#   'q_geob': 4.27,
#   'gamma_sb': 2.1,
#   's_statb': 1.65,
#   'beta1b': 0.56,
#   'beta2b': 0.84,
#   'Pmaxb': 0.35,
#   'mub': 0.06,
#   'p_weert': 6.09,
#   'q_weert': 13.37,
#   'enh_fact_da_dummy2d_scalar': 1.5,
#   'enh_intg_da_dummy2d_scalar': 0.04,
#   'n_glen_da_dummy2d_scalar': 2.35,
#   'zsb': 0.33,
#   'zlb': 0.74,
#   'zbb': 0.0,
#   'temp_cb': 0.37,
#   'temp_rb': 0.97,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_m21ka)
# Out:
# [2.96755212e+15]
# [2.9675492e+15]
# [2.96755215e+15]
# ({'c_slide_initb': 5.91,
#   'delta_tda_constb': 4.49,
#   'c_dis_dab': 0.3,
#   'q_geob': 0.0,
#   'gamma_sb': 0.41,
#   's_statb': 3.17,
#   'beta1b': 1.12,
#   'beta2b': 1.16,
#   'Pmaxb': 0.83,
#   'mub': 0.0,
#   'RHO_Ab': 0.07,
#   'time_lag_asthb': 0.01,
#   'flex_rig_lithb': 0.13,
#   'p_weert': 4.51,
#   'q_weert': 5.62,
#   'enh_fact_da_dummy2d_scalar': 1.95,
#   'enh_intg_da_dummy2d_scalar': 0.11,
#   'n_glen_da_dummy2d_scalar': 1.7,
#   'zsb': 22.42,
#   'zlb': 40.64,
#   'zbb': 0.0,
#   'temp_cb': 2.58,
#   'omega_cb': 0.84,
#   'age_cb': 0.0,
#   'delta_tdab': 2.02},
#  {'c_slide_initb': 10.85,
#   'delta_tda_constb': 11.82,
#   'c_dis_dab': 0.59,
#   'q_geob': 0.26,
#   'gamma_sb': 1.48,
#   's_statb': 9.95,
#   'beta1b': 3.43,
#   'beta2b': 3.47,
#   'Pmaxb': 2.46,
#   'mub': 0.03,
#   'RHO_Ab': 0.02,
#   'time_lag_asthb': 0.4,
#   'flex_rig_lithb': 1.71,
#   'p_weert': 8.27,
#   'q_weert': 9.58,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_BM5_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_BM5_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_BM5_m21ka)
# Out:
# [25458.69856283]
# [25458.58055945]
# [25458.69940122]
# ({'c_slide_initb': 11.04,
#   'delta_tda_constb': 4.99,
#   'c_dis_dab': 0.75,
#   'q_geob': 0.0,
#   'gamma_sb': 0.31,
#   's_statb': 3.81,
#   'beta1b': 1.18,
#   'beta2b': 1.58,
#   'Pmaxb': 0.95,
#   'mub': 0.0,
#   'RHO_Ab': 0.29,
#   'time_lag_asthb': 0.01,
#   'flex_rig_lithb': 0.23,
#   'p_weert': 1.37,
#   'q_weert': 2.27,
#   'enh_fact_da_dummy2d_scalar': 4.29,
#   'enh_intg_da_dummy2d_scalar': 0.19,
#   'n_glen_da_dummy2d_scalar': 3.18,
#   'zsb': 19.8,
#   'zlb': 35.84,
#   'zbb': 0.0,
#   'temp_cb': 3.69,
#   'omega_cb': 1.22,
#   'age_cb': 0.0,
#   'delta_tdab': 3.01},
#  {'c_slide_initb': 19.99,
#   'delta_tda_constb': 12.32,
#   'c_dis_dab': 1.37,
#   'q_geob': 0.71,
#   'gamma_sb': 0.94,
#   's_statb': 7.43,
#   'beta1b': 2.34,
#   'beta2b': 3.14,
#   'Pmaxb': 1.86,
#   'mub': 0.0,
#   'RHO_Ab': 0.7,
#   'time_lag_asthb': 0.21,
#   'flex_rig_lithb': 1.97,
#   'p_weert': 6.6,
#   'q_weert': 8.9,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_ZSC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_ZSC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_ZSC_m21ka)
# Out:
# [81612709.69193996]
# [81612709.58778511]
# [81612709.5655919]
# ({'c_slide_initb': 1.14,
#   'delta_tda_constb': 0.76,
#   'c_dis_dab': 0.01,
#   'q_geob': 0.0,
#   'gamma_sb': 0.06,
#   's_statb': 0.18,
#   'beta1b': 0.05,
#   'beta2b': 0.05,
#   'Pmaxb': 0.04,
#   'mub': 0.0,
#   'RHO_Ab': 0.02,
#   'time_lag_asthb': 0.05,
#   'flex_rig_lithb': 0.1,
#   'p_weert': 0.18,
#   'q_weert': 0.13,
#   'enh_fact_da_dummy2d_scalar': 0.17,
#   'enh_intg_da_dummy2d_scalar': 0.02,
#   'n_glen_da_dummy2d_scalar': 0.29,
#   'zsb': 3.05,
#   'zlb': 92.59,
#   'zbb': 0.0,
#   'temp_cb': 0.54,
#   'omega_cb': 0.18,
#   'age_cb': 0.0,
#   'delta_tdab': 0.38},
#  {'c_slide_initb': 9.27,
#   'delta_tda_constb': 14.12,
#   'c_dis_dab': 0.32,
#   'q_geob': 0.3,
#   'gamma_sb': 1.82,
#   's_statb': 10.6,
#   'beta1b': 3.73,
#   'beta2b': 3.43,
#   'Pmaxb': 2.67,
#   'mub': 0.0,
#   'RHO_Ab': 1.07,
#   'time_lag_asthb': 0.54,
#   'flex_rig_lithb': 1.81,
#   'p_weert': 2.52,
#   'q_weert': 3.43,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_ZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_ZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_ZLC_m21ka)
# Out:
# [16853.07305357]
# [16853.06812722]
# [16853.07066573]
# ({'c_slide_initb': 0.25,
#   'delta_tda_constb': 0.16,
#   'c_dis_dab': 0.01,
#   'q_geob': 0.0,
#   'gamma_sb': 0.01,
#   's_statb': 0.09,
#   'beta1b': 0.03,
#   'beta2b': 0.03,
#   'Pmaxb': 0.02,
#   'mub': 0.0,
#   'RHO_Ab': 0.5,
#   'time_lag_asthb': 0.04,
#   'flex_rig_lithb': 0.59,
#   'p_weert': 0.1,
#   'q_weert': 0.2,
#   'enh_fact_da_dummy2d_scalar': 0.01,
#   'enh_intg_da_dummy2d_scalar': 0.0,
#   'n_glen_da_dummy2d_scalar': 0.01,
#   'zsb': 1.95,
#   'zlb': 95.71,
#   'zbb': 0.0,
#   'temp_cb': 0.13,
#   'omega_cb': 0.04,
#   'age_cb': 0.0,
#   'delta_tdab': 0.1},
#  {'c_slide_initb': 10.5,
#   'delta_tda_constb': 10.81,
#   'c_dis_dab': 0.48,
#   'q_geob': 0.2,
#   'gamma_sb': 1.98,
#   's_statb': 4.04,
#   'beta1b': 1.4,
#   'beta2b': 1.52,
#   'Pmaxb': 0.99,
#   'mub': 0.03,
#   'RHO_Ab': 6.43,
#   'time_lag_asthb': 1.06,
#   'flex_rig_lithb': 8.74,
#   'p_weert': 3.32,
#   'q_weert': 6.44,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_m21ka)
# Out:
# [246454.98582613]
# [246455.683177]
# [246454.98989323]
# ({'c_slide_initb': 5.2,
#   'delta_tda_constb': 3.07,
#   'c_dis_dab': 0.08,
#   'q_geob': 0.0,
#   'gamma_sb': 0.58,
#   's_statb': 0.57,
#   'beta1b': 0.2,
#   'beta2b': 0.25,
#   'Pmaxb': 0.16,
#   'mub': 0.0,
#   'RHO_Ab': 0.32,
#   'time_lag_asthb': 0.01,
#   'flex_rig_lithb': 0.34,
#   'p_weert': 1.34,
#   'q_weert': 2.06,
#   'enh_fact_da_dummy2d_scalar': 5.16,
#   'enh_intg_da_dummy2d_scalar': 0.07,
#   'n_glen_da_dummy2d_scalar': 4.05,
#   'zsb': 27.85,
#   'zlb': 22.13,
#   'zbb': 0.0,
#   'temp_cb': 6.01,
#   'omega_cb': 1.93,
#   'age_cb': 17.74,
#   'delta_tdab': 0.91},
#  {'c_slide_initb': 12.46,
#   'delta_tda_constb': 10.05,
#   'c_dis_dab': 0.22,
#   'q_geob': 0.45,
#   'gamma_sb': 2.87,
#   's_statb': 3.08,
#   'beta1b': 0.98,
#   'beta2b': 1.76,
#   'Pmaxb': 0.85,
#   'mub': 0.01,
#   'RHO_Ab': 1.87,
#   'time_lag_asthb': 0.36,
#   'flex_rig_lithb': 1.62,
#   'p_weert': 1.45,
#   'q_weert': 1.67,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FBM5_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FBM5_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FBM5_m21ka)
# Out:
# [165.07318536]
# [165.08245526]
# [165.07652202]
# ({'c_slide_initb': 5.97,
#   'delta_tda_constb': 4.71,
#   'c_dis_dab': 0.23,
#   'q_geob': 0.0,
#   'gamma_sb': 0.27,
#   's_statb': 1.7,
#   'beta1b': 0.77,
#   'beta2b': 0.43,
#   'Pmaxb': 0.18,
#   'mub': 0.24,
#   'RHO_Ab': 0.07,
#   'time_lag_asthb': 0.0,
#   'flex_rig_lithb': 0.08,
#   'p_weert': 4.79,
#   'q_weert': 5.49,
#   'enh_fact_da_dummy2d_scalar': 1.94,
#   'enh_intg_da_dummy2d_scalar': 0.53,
#   'n_glen_da_dummy2d_scalar': 0.22,
#   'zsb': 21.57,
#   'zlb': 32.68,
#   'zbb': 0.0,
#   'temp_cb': 8.9,
#   'omega_cb': 2.88,
#   'age_cb': 0.0,
#   'delta_tdab': 6.32},
#  {'c_slide_initb': 11.18,
#   'delta_tda_constb': 12.79,
#   'c_dis_dab': 0.59,
#   'q_geob': 1.14,
#   'gamma_sb': 1.12,
#   's_statb': 0.91,
#   'beta1b': 0.56,
#   'beta2b': 0.56,
#   'Pmaxb': 0.9,
#   'mub': 0.62,
#   'RHO_Ab': 0.43,
#   'time_lag_asthb': 0.05,
#   'flex_rig_lithb': 1.19,
#   'p_weert': 15.58,
#   'q_weert': 10.9,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FZSC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FZSC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FZSC_m21ka)
# Out:
# [15.64346009]
# [15.65232017]
# [15.64369091]
# ({'c_slide_initb': 6.58,
#   'delta_tda_constb': 4.57,
#   'c_dis_dab': 0.23,
#   'q_geob': 0.0,
#   'gamma_sb': 0.38,
#   's_statb': 1.32,
#   'beta1b': 0.58,
#   'beta2b': 0.3,
#   'Pmaxb': 0.16,
#   'mub': 0.15,
#   'RHO_Ab': 0.31,
#   'time_lag_asthb': 0.01,
#   'flex_rig_lithb': 0.25,
#   'p_weert': 4.33,
#   'q_weert': 1.59,
#   'enh_fact_da_dummy2d_scalar': 2.81,
#   'enh_intg_da_dummy2d_scalar': 0.42,
#   'n_glen_da_dummy2d_scalar': 1.01,
#   'zsb': 20.83,
#   'zlb': 36.56,
#   'zbb': 0.0,
#   'temp_cb': 9.57,
#   'omega_cb': 3.12,
#   'age_cb': 0.0,
#   'delta_tdab': 4.92},
#  {'c_slide_initb': 12.09,
#   'delta_tda_constb': 13.44,
#   'c_dis_dab': 0.44,
#   'q_geob': 1.2,
#   'gamma_sb': 1.36,
#   's_statb': 2.41,
#   'beta1b': 0.99,
#   'beta2b': 0.14,
#   'Pmaxb': 0.21,
#   'mub': 0.42,
#   'RHO_Ab': 1.3,
#   'time_lag_asthb': 0.12,
#   'flex_rig_lithb': 1.51,
#   'p_weert': 11.36,
#   'q_weert': 8.74,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FZLC_m21ka)
# Out:
# [0.1128693]
# [0.11490439]
# [0.11311042]
# ({'c_slide_initb': 0.35,
#   'delta_tda_constb': 0.3,
#   'c_dis_dab': 0.0,
#   'q_geob': 0.0,
#   'gamma_sb': 0.01,
#   's_statb': 0.14,
#   'beta1b': 0.04,
#   'beta2b': 0.07,
#   'Pmaxb': 0.04,
#   'mub': 0.0,
#   'RHO_Ab': 0.09,
#   'time_lag_asthb': 0.01,
#   'flex_rig_lithb': 0.28,
#   'p_weert': 0.01,
#   'q_weert': 0.03,
#   'enh_fact_da_dummy2d_scalar': 0.2,
#   'enh_intg_da_dummy2d_scalar': 0.02,
#   'n_glen_da_dummy2d_scalar': 0.13,
#   'zsb': 2.13,
#   'zlb': 95.63,
#   'zbb': 0.0,
#   'temp_cb': 0.25,
#   'omega_cb': 0.08,
#   'age_cb': 0.0,
#   'delta_tdab': 0.2},
#  {'c_slide_initb': 10.38,
#   'delta_tda_constb': 13.72,
#   'c_dis_dab': 0.16,
#   'q_geob': 0.18,
#   'gamma_sb': 2.24,
#   's_statb': 6.33,
#   'beta1b': 1.99,
#   'beta2b': 3.26,
#   'Pmaxb': 1.66,
#   'mub': 0.01,
#   'RHO_Ab': 0.06,
#   'time_lag_asthb': 0.87,
#   'flex_rig_lithb': 4.96,
#   'p_weert': 2.9,
#   'q_weert': 6.01,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FAC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FAC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FAC_m21ka)
# Out:
# [2.31096763]
# [2.30792578]
# [2.31097264]
# ({'c_slide_initb': 4.47,
#   'delta_tda_constb': 3.33,
#   'c_dis_dab': 0.05,
#   'q_geob': 0.0,
#   'gamma_sb': 0.59,
#   's_statb': 0.73,
#   'beta1b': 0.23,
#   'beta2b': 0.35,
#   'Pmaxb': 0.18,
#   'mub': 0.0,
#   'RHO_Ab': 0.19,
#   'time_lag_asthb': 0.0,
#   'flex_rig_lithb': 0.35,
#   'p_weert': 0.49,
#   'q_weert': 0.17,
#   'enh_fact_da_dummy2d_scalar': 2.64,
#   'enh_intg_da_dummy2d_scalar': 0.16,
#   'n_glen_da_dummy2d_scalar': 1.21,
#   'zsb': 26.24,
#   'zlb': 23.99,
#   'zbb': 0.0,
#   'temp_cb': 6.11,
#   'omega_cb': 2.03,
#   'age_cb': 25.37,
#   'delta_tdab': 1.11},
#  {'c_slide_initb': 9.53,
#   'delta_tda_constb': 8.97,
#   'c_dis_dab': 0.04,
#   'q_geob': 0.49,
#   'gamma_sb': 3.15,
#   's_statb': 0.49,
#   'beta1b': 0.13,
#   'beta2b': 0.39,
#   'Pmaxb': 0.17,
#   'mub': 0.02,
#   'RHO_Ab': 0.77,
#   'time_lag_asthb': 0.07,
#   'flex_rig_lithb': 1.78,
#   'p_weert': 1.24,
#   'q_weert': 0.54,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_SVC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_SVC_m21ka)
# Out:
# [95874.07577948]
# [95873.96620233]
# ({'c_slide_initb': 16.39,
#   'delta_tda_constb': 11.0,
#   'c_dis_dab': 0.21,
#   'q_geob': 0.69,
#   'gamma_sb': 1.39,
#   's_statb': 6.61,
#   'beta1b': 1.98,
#   'beta2b': 2.39,
#   'Pmaxb': 1.48,
#   'mub': 0.01,
#   'RHO_Ab': 1.33,
#   'time_lag_asthb': 0.17,
#   'flex_rig_lithb': 2.58,
#   'p_weert': 8.17,
#   'q_weert': 6.23,
#   'enh_fact_da_dummy2d_scalar': 3.44,
#   'enh_intg_da_dummy2d_scalar': 0.05,
#   'n_glen_da_dummy2d_scalar': 8.86,
#   'zsb': 0.98,
#   'zlb': 7.0,
#   'zbb': 0.0,
#   'temp_cb': 4.03,
#   'omega_cb': 1.39,
#   'age_cb': 0.0,
#   'delta_tdab': 13.63},
#  {'c_slide_initb': 16.54,
#   'delta_tda_constb': 11.14,
#   'c_dis_dab': 0.2,
#   'q_geob': 3.5,
#   'gamma_sb': 2.24,
#   's_statb': 6.68,
#   'beta1b': 2.0,
#   'beta2b': 2.41,
#   'Pmaxb': 1.49,
#   'mub': 0.01,
#   'RHO_Ab': 1.5,
#   'time_lag_asthb': 0.15,
#   'flex_rig_lithb': 2.79,
#   'p_weert': 8.35,
#   'q_weert': 6.23,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FSVC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FSVC_m21ka)
# Out:
# [25629.0427405]
# [25628.16291307]
# ({'c_slide_initb': 24.17,
#   'delta_tda_constb': 15.78,
#   'c_dis_dab': 0.0,
#   'q_geob': 1.01,
#   'gamma_sb': 1.42,
#   's_statb': 3.6,
#   'beta1b': 0.56,
#   'beta2b': 1.9,
#   'Pmaxb': 0.19,
#   'mub': 0.14,
#   'RHO_Ab': 0.62,
#   'time_lag_asthb': 0.2,
#   'flex_rig_lithb': 2.25,
#   'p_weert': 1.12,
#   'q_weert': 3.55,
#   'enh_fact_da_dummy2d_scalar': 1.87,
#   'enh_intg_da_dummy2d_scalar': 0.12,
#   'n_glen_da_dummy2d_scalar': 2.94,
#   'zsb': 0.75,
#   'zlb': 7.27,
#   'zbb': 0.0,
#   'temp_cb': 3.24,
#   'omega_cb': 1.11,
#   'age_cb': 0.0,
#   'delta_tdab': 26.2},
#  {'c_slide_initb': 23.87,
#   'delta_tda_constb': 15.73,
#   'c_dis_dab': 0.0,
#   'q_geob': 4.42,
#   'gamma_sb': 2.15,
#   's_statb': 3.59,
#   'beta1b': 0.56,
#   'beta2b': 1.89,
#   'Pmaxb': 0.2,
#   'mub': 0.14,
#   'RHO_Ab': 0.6,
#   'time_lag_asthb': 0.2,
#   'flex_rig_lithb': 2.43,
#   'p_weert': 1.15,
#   'q_weert': 3.5,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FSVC_nudged_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FSVC_nudged_m21ka)
# Out:
# [210.950893]
# [0.09371983]
# ({'c_slide_initb': 42.97,
#   'delta_tda_constb': 5.6,
#   'c_dis_dab': 0.17,
#   'q_geob': 1.48,
#   'gamma_sb': 0.38,
#   's_statb': 1.85,
#   'beta1b': 0.79,
#   'beta2b': 0.48,
#   'Pmaxb': 0.55,
#   'mub': 0.01,
#   'RHO_Ab': 0.06,
#   'time_lag_asthb': 0.01,
#   'flex_rig_lithb': 0.21,
#   'p_weert': 1.94,
#   'q_weert': 12.47,
#   'enh_fact_da_dummy2d_scalar': 7.15,
#   'enh_intg_da_dummy2d_scalar': 0.01,
#   'n_glen_da_dummy2d_scalar': 5.77,
#   'zsb': 1.91,
#   'zlb': 2.14,
#   'zbb': 0.0,
#   'temp_cb': 6.22,
#   'omega_cb': 2.13,
#   'age_cb': 0.0,
#   'delta_tdab': 5.69},
#  {'c_slide_initb': 33.2,
#   'delta_tda_constb': 7.59,
#   'c_dis_dab': 0.14,
#   'q_geob': 5.16,
#   'gamma_sb': 2.1,
#   's_statb': 0.74,
#   'beta1b': 0.2,
#   'beta2b': 0.17,
#   'Pmaxb': 0.12,
#   'mub': 0.04,
#   'RHO_Ab': 0.02,
#   'time_lag_asthb': 0.1,
#   'flex_rig_lithb': 0.21,
#   'p_weert': 3.33,
#   'q_weert': 23.1,
#   'enh_fact_da_dummy2d_scalar': 3.29,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_BM5_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_BM5_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_BM5_m21ka)
# Out:
# [98858.94292971]
# [98859.07154431]
# [98858.94681525]
# ({'c_slide_initb': 5.26,
#   'c_dis_dab': 0.23,
#   'q_geob': 0.0,
#   'gamma_sb': 0.76,
#   's_statb': 1.47,
#   'beta1b': 0.59,
#   'beta2b': 0.5,
#   'Pmaxb': 0.44,
#   'mub': 0.0,
#   'p_weert': 0.29,
#   'q_weert': 1.22,
#   'enh_fact_da_dummy2d_scalar': 0.51,
#   'enh_intg_da_dummy2d_scalar': 0.05,
#   'n_glen_da_dummy2d_scalar': 0.32,
#   'zsb': 10.75,
#   'zlb': 19.75,
#   'zbb': 0.0,
#   'temp_cb': 0.89,
#   'temp_rb': 0.69,
#   'omega_cb': 1.44,
#   'age_cb': 45.57,
#   'delta_tdab': 9.28},
#  {'c_slide_initb': 10.24,
#   'c_dis_dab': 0.38,
#   'q_geob': 0.58,
#   'gamma_sb': 3.78,
#   's_statb': 1.73,
#   'beta1b': 0.85,
#   'beta2b': 0.66,
#   'Pmaxb': 0.58,
#   'mub': 0.02,
#   'p_weert': 0.3,
#   'q_weert': 1.17,
#   'enh_fact_da_dummy2d_scalar': 0.13,
#   'enh_intg_da_dummy2d_scalar': 2.03,
#   'n_glen_da_dummy2d_scalar': 0.61,
#   'zsb': 2.08,
#   'zlb': 8.11,
#   'zbb': 0.0,
#   'temp_cb': 0.83,
# ...

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_ZSC_ZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_ZSC_ZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_ZSC_ZLC_m21ka)
# Out:
# [81876017.75081977]
# [81876018.33908905]
# [81876017.62615089]
# ({'c_slide_initb': 1.16,
#   'delta_tda_constb': 0.77,
#   'c_dis_dab': 0.01,
#   'q_geob': 0.0,
#   'gamma_sb': 0.07,
#   's_statb': 0.18,
#   'beta1b': 0.05,
#   'beta2b': 0.05,
#   'Pmaxb': 0.04,
#   'mub': 0.0,
#   'RHO_Ab': 0.02,
#   'time_lag_asthb': 0.05,
#   'flex_rig_lithb': 0.1,
#   'p_weert': 0.17,
#   'q_weert': 0.11,
#   'enh_fact_da_dummy2d_scalar': 0.12,
#   'enh_intg_da_dummy2d_scalar': 0.02,
#   'n_glen_da_dummy2d_scalar': 0.25,
#   'zsb': 3.23,
#   'zlb': 92.27,
#   'zbb': 0.0,
#   'temp_cb': 0.57,
#   'omega_cb': 0.19,
#   'age_cb': 0.19,
#   'delta_tdab': 0.38},
#  {'c_slide_initb': 9.35,
#   'delta_tda_constb': 14.35,
#   'c_dis_dab': 0.3,
#   'q_geob': 0.32,
#   'gamma_sb': 1.89,
#   's_statb': 10.31,
#   'beta1b': 3.64,
#   'beta2b': 3.27,
#   'Pmaxb': 2.59,
#   'mub': 0.0,
#   'RHO_Ab': 0.94,
#   'time_lag_asthb': 0.56,
#   'flex_rig_lithb': 1.81,
#   'p_weert': 2.39,
#   'q_weert': 3.27,
# ...
