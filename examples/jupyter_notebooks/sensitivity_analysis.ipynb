# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# Paths and stuff
import os
import sys

sys.path.append('/home/shreyas/pySICOPOLIS/src')
from pySICOPOLIS import *

# %%
ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_13point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_13point5CS_spinup_0ka0005.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_13point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_13point5CS_spinup_0ka0006.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_13point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_13point5CS_spinup_0ka0009.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_final = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp0006.nc')

ds_adj_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp.nc')
ds_adj_BM5_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_BM5_m21ka_pkp.nc')
ds_adj_ZSC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZSC_m21ka_pkp.nc')
ds_adj_ZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZLC_m21ka_pkp.nc')
ds_adj_AC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_m21ka_pkp.nc')
ds_adj_FBM5_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FBM5_m21ka_pkp.nc')
ds_adj_FZSC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZSC_m21ka_pkp.nc')
ds_adj_FZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZLC_m21ka_pkp.nc')
ds_adj_FAC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FAC_m21ka_pkp.nc')
ds_adj_SVC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_SVC_m21ka_pkp.nc')
ds_adj_FSVC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FSVC_m21ka_pkp.nc')
ds_adj_SVC_nudged_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_SVC_m21ka_pkp.nc')
ds_adj_FSVC_nudged_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_FSVC_m21ka_pkp.nc')
ds_adj_AC_BM5_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_m21ka_pkp.nc')
ds_adj_AC_BM5_ZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m21ka_pkp.nc')
ds_adj_AC_ZSC_ZLC_m21ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_ZSC_ZLC_m21ka_pkp.nc')

ds_adj_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp.nc')
ds_adj_BM5_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_BM5_m11ka_pkp.nc')
ds_adj_ZSC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZSC_m11ka_pkp.nc')
ds_adj_ZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZLC_m11ka_pkp.nc')
ds_adj_AC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_m11ka_pkp.nc')
ds_adj_FBM5_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FBM5_m11ka_pkp.nc')
ds_adj_FZSC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZSC_m11ka_pkp.nc')
ds_adj_FZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZLC_m11ka_pkp.nc')
ds_adj_FAC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FAC_m11ka_pkp.nc')
ds_adj_SVC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_SVC_m11ka_pkp.nc')
ds_adj_FSVC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FSVC_m11ka_pkp.nc')
ds_adj_SVC_nudged_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_SVC_m11ka_pkp.nc')
ds_adj_FSVC_nudged_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_nudged_CT4_BH0_FSVC_m11ka_pkp.nc')
ds_adj_AC_BM5_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_m11ka_pkp.nc')
ds_adj_AC_BM5_ZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m11ka_pkp.nc')
ds_adj_AC_ZSC_ZLC_m11ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_ZSC_ZLC_m11ka_pkp.nc')

ds_adj_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp.nc')
ds_adj_BM5_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_BM5_m1ka_pkp.nc')
ds_adj_ZSC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZSC_m1ka_pkp.nc')
ds_adj_ZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_ZLC_m1ka_pkp.nc')
ds_adj_AC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_m1ka_pkp.nc')
ds_adj_FBM5_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FBM5_m1ka_pkp.nc')
ds_adj_FZSC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZSC_m1ka_pkp.nc')
ds_adj_FZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FZLC_m1ka_pkp.nc')
ds_adj_FAC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_FAC_m1ka_pkp.nc')
ds_adj_AC_BM5_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_m1ka_pkp.nc')
ds_adj_AC_BM5_ZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_BM5_ZLC_m1ka_pkp.nc')
ds_adj_AC_ZSC_ZLC_m1ka = xr.open_dataset('/home/shreyas/update_to_develop_sicopolis/sicopolis_ad/src/subroutines/tapenade/ad_io/ad_output_adj_grl40_bm5_paleo17a_CT4_BH0_AC_ZSC_ZLC_m1ka_pkp.nc')

# OLD VALUES
# fc_m21ka      = 2976669080298474.5
# fc_BM5_m21ka  = 2354462.4562517381
# fc_AC_m21ka   = 600895.34838571900
# fc_FBM5_m21ka = 6.0211251125695010E-003
# fc_FAC_m21ka  = 3.5073427819192142E-005
# fc_SVC_m21ka  = 7.0293210428090007E-009
# fc_FSVC_m21ka = 1.5042424778048501E-015
# fc_SVC_nudged_m21ka  = 8.4357224666537152E-009
# fc_FSVC_nudged_m21ka = 8.9188591109936969E-009

# fc_m11ka      = 2976666880641083.0
# fc_BM5_m11ka  = 2354091.9959212681
# fc_AC_m11ka   = 600894.93683796015
# fc_FBM5_m11ka = 1.0983246117881599E-008
# fc_FAC_m11ka  = 1.5671972439614768E-009
# fc_SVC_m11ka  = 7.0294415690894787E-009
# fc_FSVC_m11ka = 3.0056361481634127E-022
# fc_SVC_nudged_m11ka  = 8.6584001255661731E-009
# fc_FSVC_nudged_m11ka = 8.9971011209051522E-009

# fc_m1ka       = 2976640266349614.5
# fc_BM5_m1ka   = 2354207.6310759312
# fc_AC_m1ka    = 600910.80585193611
# fc_FBM5_m1ka  = 4.5715588400844547E-002
# fc_FAC_m1ka   = 6.0115708256628514E-004

# %%
def non_dim_sensitivities(ds_init, ds_output_adj):
    non_dim_grads = {}
    fc = ds_output_adj['fc'].data
    print(fc)
    non_dim_grads['c_slide_initb'] = np.sum(np.abs(ds_output_adj['xx_c_slide_initb'].data)) * 13.5 / fc[0]
    # non_dim_grads['delta_tda_constb'] = np.sum(np.abs(ds_output_adj['xx_delta_tda_constb'].data)) * 3.74 / fc
    non_dim_grads['c_dis_dab'] = np.sum(np.abs(ds_output_adj['xx_c_dis_dab'].data)) * 15659.0 / fc[0]
    non_dim_grads['q_geob'] = np.sum(np.abs(ds_output_adj['xx_q_geob'].data * ds_init['q_geo'].data)) / fc[0]
    non_dim_grads['Hb'] = np.sum(np.abs(ds_output_adj['xx_Hb'].data * ds_init['H'].data)) / fc[0]
    non_dim_grads['gamma_sb'] = np.sum(np.abs(ds_output_adj['xx_gamma_sb'].data)) * 0.070458 / fc[0]
    non_dim_grads['s_statb'] = np.sum(np.abs(ds_output_adj['xx_s_statb'].data)) * 5.0 / fc[0]
    non_dim_grads['beta1b'] = np.sum(np.abs(ds_output_adj['xx_beta1b'].data)) * 2.73 / fc[0]
    non_dim_grads['beta2b'] = np.sum(np.abs(ds_output_adj['xx_beta2b'].data)) * 7.28 / fc[0]
    non_dim_grads['Pmaxb'] = np.sum(np.abs(ds_output_adj['xx_Pmaxb'].data)) * 0.6 / fc[0]
    non_dim_grads['mub'] = np.sum(np.abs(ds_output_adj['xx_mub'].data)) * 9.7155 / fc[0]
    non_dim_grads['RHO_Ab'] = np.sum(np.abs(ds_output_adj['xx_RHO_Ab'].data)) * 3300.0 / fc[0]
    non_dim_grads['time_lag_asthb'] = np.sum(np.abs(ds_output_adj['xx_time_lag_asthb'].data)) * 3000.0 / fc[0]
    non_dim_grads['zsb'] = np.sum(np.abs(ds_output_adj['xx_zsb'].data * ds_init['zs'].data)) / fc[0]
    non_dim_grads['zl0b'] = np.sum(np.abs(ds_output_adj['xx_zl0b'].data * ds_init['zl0'].data)) / fc[0]
    non_dim_grads['zlb'] = np.sum(np.abs(ds_output_adj['xx_zlb'].data * ds_init['zl'].data)) / fc[0]
    non_dim_grads['zbb'] = np.sum(np.abs(ds_output_adj['xx_zbb'].data * ds_init['zb'].data)) / fc[0]
    non_dim_grads['temp_cb'] = np.sum(np.abs(ds_output_adj['xx_temp_cb'].data * ds_init['temp_c'].data)) / fc[0]
    non_dim_grads['vx_cb'] = np.sum(np.abs(ds_output_adj['xx_vx_cb'].data * ds_init['vx_c'].data)) / fc[0]
    non_dim_grads['vy_cb'] = np.sum(np.abs(ds_output_adj['xx_vy_cb'].data * ds_init['vy_c'].data)) / fc[0]
    non_dim_grads['vz_cb'] = np.sum(np.abs(ds_output_adj['xx_vz_cb'].data * ds_init['vz_c'].data)) / fc[0]
    non_dim_grads['age_cb'] = np.sum(np.abs(ds_output_adj['xx_age_cb'].data * ds_init['age_c'].data)) / fc[0] # * 3.156e+7 # year2sec
    non_dim_grads['delta_tdab'] = np.sum(np.abs(ds_output_adj['xx_delta_tdab'].data)) * 3.74 / fc[0]
    
    # Sum of all calculated non-dimensional sensitivities
    total_sum = sum(non_dim_grads.values())
    
    # Normalize each field to percentage and round to two decimal places
    non_dim_grads_percentage = {key: np.round((value / total_sum) * 100, 2) for key, value in non_dim_grads.items()}
    
    return non_dim_grads_percentage

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_m21ka)
# Out:
# [2.97664027e+15]
# [2.97666688e+15]
# [2.97666908e+15]
# ({'c_slide_initb': 3.5,
#   'c_dis_dab': 2.68,
#   'q_geob': 0.0,
#   'Hb': 46.15,
#   'gamma_sb': 0.33,
#   's_statb': 9.81,
#   'beta1b': 2.02,
#   'beta2b': 4.81,
#   'Pmaxb': 3.23,
#   'mub': 0.03,
#   'RHO_Ab': 1.06,
#   'time_lag_asthb': 0.06,
#   'zsb': 0.05,
#   'zl0b': 3.19,
#   'zlb': 11.25,
#   'zbb': 0.0,
#   'temp_cb': 2.87,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 8.95},
#  {'c_slide_initb': 4.31,
#   'c_dis_dab': 2.34,
#   'q_geob': 0.13,
#   'Hb': 0.94,
#   'gamma_sb': 0.53,
#   's_statb': 13.6,
#   'beta1b': 2.93,
#   'beta2b': 6.29,
#   'Pmaxb': 4.41,
#   'mub': 0.28,
#   'RHO_Ab': 12.25,
#   'time_lag_asthb': 1.68,
#   'zsb': 0.0,
#   'zl0b': 28.09,
#   'zlb': 1.9,
#   'zbb': 0.0,
#   'temp_cb': 4.61,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 15.71},
#  {'c_slide_initb': 4.1,
#   'c_dis_dab': 2.22,
#   'q_geob': 0.79,
#   'Hb': 0.77,
#   'gamma_sb': 0.74,
#   's_statb': 12.8,
#   'beta1b': 2.76,
#   'beta2b': 5.91,
#   'Pmaxb': 4.15,
#   'mub': 0.28,
#   'RHO_Ab': 14.4,
#   'time_lag_asthb': 1.56,
#   'zsb': 0.0,
#   'zl0b': 30.85,
#   'zlb': 0.63,
#   'zbb': 0.0,
#   'temp_cb': 2.94,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 15.09})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_BM5_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_BM5_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_BM5_m21ka)
# Out:
# [1177103.81553797]
# [1177045.99796063]
# [1177231.22812587]
# ({'c_slide_initb': 4.68,
#   'c_dis_dab': 4.4,
#   'q_geob': 0.0,
#   'Hb': 28.8,
#   'gamma_sb': 0.27,
#   's_statb': 7.93,
#   'beta1b': 1.64,
#   'beta2b': 3.92,
#   'Pmaxb': 2.61,
#   'mub': 0.02,
#   'RHO_Ab': 4.22,
#   'time_lag_asthb': 0.17,
#   'zsb': 0.06,
#   'zl0b': 9.17,
#   'zlb': 18.55,
#   'zbb': 0.0,
#   'temp_cb': 6.29,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 7.26},
#  {'c_slide_initb': 4.6,
#   'c_dis_dab': 3.35,
#   'q_geob': 0.23,
#   'Hb': 1.05,
#   'gamma_sb': 0.47,
#   's_statb': 9.77,
#   'beta1b': 2.17,
#   'beta2b': 4.68,
#   'Pmaxb': 3.25,
#   'mub': 0.28,
#   'RHO_Ab': 13.72,
#   'time_lag_asthb': 0.85,
#   'zsb': 0.01,
#   'zl0b': 34.7,
#   'zlb': 3.2,
#   'zbb': 0.0,
#   'temp_cb': 5.45,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 12.23},
#  {'c_slide_initb': 4.25,
#   'c_dis_dab': 3.07,
#   'q_geob': 1.2,
#   'Hb': 1.01,
#   'gamma_sb': 0.93,
#   's_statb': 8.85,
#   'beta1b': 1.97,
#   'beta2b': 4.24,
#   'Pmaxb': 2.94,
#   'mub': 0.27,
#   'RHO_Ab': 15.32,
#   'time_lag_asthb': 0.81,
#   'zsb': 0.01,
#   'zl0b': 38.67,
#   'zlb': 1.24,
#   'zbb': 0.0,
#   'temp_cb': 3.75,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 11.47})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_ZSC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_ZSC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_ZSC_m21ka)
# Out:
# [1143350.16214472]
# [1143384.45671521]
# [1143410.2544898]
# ({'c_slide_initb': 3.87,
#   'c_dis_dab': 1.88,
#   'q_geob': 0.0,
#   'Hb': 34.34,
#   'gamma_sb': 0.26,
#   's_statb': 8.33,
#   'beta1b': 1.72,
#   'beta2b': 3.79,
#   'Pmaxb': 2.68,
#   'mub': 0.03,
#   'RHO_Ab': 4.31,
#   'time_lag_asthb': 0.2,
#   'zsb': 0.06,
#   'zl0b': 9.97,
#   'zlb': 16.75,
#   'zbb': 0.0,
#   'temp_cb': 4.36,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 7.46},
#  {'c_slide_initb': 3.59,
#   'c_dis_dab': 2.45,
#   'q_geob': 0.13,
#   'Hb': 0.9,
#   'gamma_sb': 0.6,
#   's_statb': 15.91,
#   'beta1b': 3.58,
#   'beta2b': 6.45,
#   'Pmaxb': 5.33,
#   'mub': 0.31,
#   'RHO_Ab': 8.31,
#   'time_lag_asthb': 1.55,
#   'zsb': 0.0,
#   'zl0b': 27.85,
#   'zlb': 2.34,
#   'zbb': 0.0,
#   'temp_cb': 3.98,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 16.73},
#  {'c_slide_initb': 3.43,
#   'c_dis_dab': 2.28,
#   'q_geob': 0.73,
#   'Hb': 1.75,
#   'gamma_sb': 1.01,
#   's_statb': 14.37,
#   'beta1b': 3.24,
#   'beta2b': 5.82,
#   'Pmaxb': 4.81,
#   'mub': 0.28,
#   'RHO_Ab': 10.05,
#   'time_lag_asthb': 1.36,
#   'zsb': 0.01,
#   'zl0b': 30.17,
#   'zlb': 1.68,
#   'zbb': 0.0,
#   'temp_cb': 3.61,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 15.41})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_ZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_ZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_ZLC_m21ka)
# Out:
# [13402.85879606]
# [13402.71053841]
# [13402.89568265]
# ({'c_slide_initb': 0.58,
#   'c_dis_dab': 0.21,
#   'q_geob': 0.0,
#   'Hb': 7.11,
#   'gamma_sb': 0.01,
#   's_statb': 1.18,
#   'beta1b': 0.22,
#   'beta2b': 0.57,
#   'Pmaxb': 0.35,
#   'mub': 0.0,
#   'RHO_Ab': 12.07,
#   'time_lag_asthb': 0.48,
#   'zsb': 0.02,
#   'zl0b': 29.18,
#   'zlb': 46.31,
#   'zbb': 0.0,
#   'temp_cb': 0.66,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 1.03},
#  {'c_slide_initb': 1.73,
#   'c_dis_dab': 1.1,
#   'q_geob': 0.04,
#   'Hb': 0.81,
#   'gamma_sb': 0.44,
#   's_statb': 8.27,
#   'beta1b': 1.64,
#   'beta2b': 4.12,
#   'Pmaxb': 2.59,
#   'mub': 0.05,
#   'RHO_Ab': 19.33,
#   'time_lag_asthb': 1.2,
#   'zsb': 0.0,
#   'zl0b': 45.81,
#   'zlb': 2.43,
#   'zbb': 0.0,
#   'temp_cb': 2.79,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 7.66},
#  {'c_slide_initb': 1.66,
#   'c_dis_dab': 1.04,
#   'q_geob': 0.35,
#   'Hb': 0.41,
#   'gamma_sb': 0.59,
#   's_statb': 7.82,
#   'beta1b': 1.55,
#   'beta2b': 3.88,
#   'Pmaxb': 2.45,
#   'mub': 0.05,
#   'RHO_Ab': 20.99,
#   'time_lag_asthb': 1.11,
#   'zsb': 0.0,
#   'zl0b': 48.46,
#   'zlb': 0.38,
#   'zbb': 0.0,
#   'temp_cb': 1.81,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 7.45})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_m21ka)
# Out:
# [938732.36313322]
# [938724.92321081]
# [938728.30827719]
# ({'c_slide_initb': 1.27,
#   'c_dis_dab': 0.21,
#   'q_geob': 0.0,
#   'Hb': 27.89,
#   'gamma_sb': 0.22,
#   's_statb': 0.69,
#   'beta1b': 0.15,
#   'beta2b': 0.36,
#   'Pmaxb': 0.24,
#   'mub': 0.0,
#   'RHO_Ab': 1.95,
#   'time_lag_asthb': 0.05,
#   'zsb': 0.37,
#   'zl0b': 3.0,
#   'zlb': 4.3,
#   'zbb': 0.0,
#   'temp_cb': 2.61,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 56.03,
#   'delta_tdab': 0.65},
#  {'c_slide_initb': 3.7,
#   'c_dis_dab': 0.87,
#   'q_geob': 0.11,
#   'Hb': 4.61,
#   'gamma_sb': 1.23,
#   's_statb': 7.91,
#   'beta1b': 1.45,
#   'beta2b': 5.16,
#   'Pmaxb': 2.42,
#   'mub': 0.09,
#   'RHO_Ab': 14.66,
#   'time_lag_asthb': 1.73,
#   'zsb': 0.04,
#   'zl0b': 23.85,
#   'zlb': 2.42,
#   'zbb': 0.0,
#   'temp_cb': 6.17,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 14.35,
#   'delta_tdab': 9.24},
#  {'c_slide_initb': 3.54,
#   'c_dis_dab': 0.83,
#   'q_geob': 0.73,
#   'Hb': 3.04,
#   'gamma_sb': 2.23,
#   's_statb': 6.81,
#   'beta1b': 1.25,
#   'beta2b': 4.45,
#   'Pmaxb': 2.08,
#   'mub': 0.08,
#   'RHO_Ab': 18.92,
#   'time_lag_asthb': 1.49,
#   'zsb': 0.02,
#   'zl0b': 29.38,
#   'zlb': 1.55,
#   'zbb': 0.0,
#   'temp_cb': 5.56,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 9.71,
#   'delta_tdab': 8.33})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FBM5_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FBM5_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FBM5_m21ka)
# Out:
# [0.02285779]
# [5.49162306e-09]
# [0.00301056]
# ({'c_slide_initb': 4.83,
#   'c_dis_dab': 2.63,
#   'q_geob': 0.0,
#   'Hb': 28.83,
#   'gamma_sb': 0.28,
#   's_statb': 14.29,
#   'beta1b': 2.37,
#   'beta2b': 8.74,
#   'Pmaxb': 4.04,
#   'mub': 0.06,
#   'RHO_Ab': 1.59,
#   'time_lag_asthb': 0.13,
#   'zsb': 0.05,
#   'zl0b': 3.89,
#   'zlb': 10.4,
#   'zbb': 0.0,
#   'temp_cb': 4.31,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 13.54},
#  {'c_slide_initb': 5.31,
#   'c_dis_dab': 3.24,
#   'q_geob': 0.17,
#   'Hb': 0.78,
#   'gamma_sb': 0.59,
#   's_statb': 16.71,
#   'beta1b': 2.97,
#   'beta2b': 9.99,
#   'Pmaxb': 4.99,
#   'mub': 0.2,
#   'RHO_Ab': 7.96,
#   'time_lag_asthb': 1.52,
#   'zsb': 0.0,
#   'zl0b': 21.98,
#   'zlb': 1.86,
#   'zbb': 0.0,
#   'temp_cb': 3.65,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 18.08},
#  {'c_slide_initb': 4.0,
#   'c_dis_dab': 3.4,
#   'q_geob': 1.42,
#   'Hb': 0.77,
#   'gamma_sb': 1.1,
#   's_statb': 14.06,
#   'beta1b': 2.82,
#   'beta2b': 7.19,
#   'Pmaxb': 4.6,
#   'mub': 0.4,
#   'RHO_Ab': 11.72,
#   'time_lag_asthb': 1.02,
#   'zsb': 0.0,
#   'zl0b': 27.97,
#   'zlb': 0.75,
#   'zbb': 0.0,
#   'temp_cb': 3.45,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 15.33})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FZSC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FZSC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FZSC_m21ka)
# Out:
# [0.07062479]
# [7.11213887e-08]
# [0.05450791]
# ({'c_slide_initb': 3.65,
#   'c_dis_dab': 1.99,
#   'q_geob': 0.0,
#   'Hb': 31.22,
#   'gamma_sb': 0.25,
#   's_statb': 9.53,
#   'beta1b': 2.07,
#   'beta2b': 4.75,
#   'Pmaxb': 3.35,
#   'mub': 0.04,
#   'RHO_Ab': 3.29,
#   'time_lag_asthb': 0.23,
#   'zsb': 0.08,
#   'zl0b': 7.4,
#   'zlb': 17.51,
#   'zbb': 0.0,
#   'temp_cb': 5.72,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 8.94},
#  {'c_slide_initb': 3.75,
#   'c_dis_dab': 2.27,
#   'q_geob': 0.19,
#   'Hb': 0.82,
#   'gamma_sb': 0.59,
#   's_statb': 13.8,
#   'beta1b': 3.58,
#   'beta2b': 5.27,
#   'Pmaxb': 5.33,
#   'mub': 0.8,
#   'RHO_Ab': 9.01,
#   'time_lag_asthb': 1.19,
#   'zsb': 0.0,
#   'zl0b': 31.93,
#   'zlb': 2.81,
#   'zbb': 0.0,
#   'temp_cb': 3.93,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 14.72},
#  {'c_slide_initb': 3.05,
#   'c_dis_dab': 2.29,
#   'q_geob': 0.79,
#   'Hb': 1.68,
#   'gamma_sb': 1.21,
#   's_statb': 14.51,
#   'beta1b': 3.13,
#   'beta2b': 6.64,
#   'Pmaxb': 4.8,
#   'mub': 0.28,
#   'RHO_Ab': 11.2,
#   'time_lag_asthb': 1.25,
#   'zsb': 0.01,
#   'zl0b': 27.08,
#   'zlb': 1.64,
#   'zbb': 0.0,
#   'temp_cb': 3.77,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 16.67})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FZLC_m21ka)
# Out:
# [3.22728765e-06]
# [6.02976057e-12]
# [3.67734265e-07]
# ({'c_slide_initb': 0.72,
#   'c_dis_dab': 0.37,
#   'q_geob': 0.0,
#   'Hb': 8.52,
#   'gamma_sb': 0.02,
#   's_statb': 1.43,
#   'beta1b': 0.31,
#   'beta2b': 0.69,
#   'Pmaxb': 0.48,
#   'mub': 0.01,
#   'RHO_Ab': 9.71,
#   'time_lag_asthb': 0.77,
#   'zsb': 0.02,
#   'zl0b': 27.04,
#   'zlb': 47.58,
#   'zbb': 0.0,
#   'temp_cb': 1.05,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 1.29},
#  {'c_slide_initb': 1.1,
#   'c_dis_dab': 0.59,
#   'q_geob': 0.04,
#   'Hb': 0.31,
#   'gamma_sb': 0.17,
#   's_statb': 2.91,
#   'beta1b': 0.64,
#   'beta2b': 1.28,
#   'Pmaxb': 0.96,
#   'mub': 0.1,
#   'RHO_Ab': 19.16,
#   'time_lag_asthb': 1.06,
#   'zsb': 0.0,
#   'zl0b': 64.89,
#   'zlb': 2.56,
#   'zbb': 0.0,
#   'temp_cb': 1.36,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 2.88},
#  {'c_slide_initb': 1.82,
#   'c_dis_dab': 2.13,
#   'q_geob': 0.43,
#   'Hb': 0.58,
#   'gamma_sb': 0.91,
#   's_statb': 15.21,
#   'beta1b': 3.22,
#   'beta2b': 6.46,
#   'Pmaxb': 4.91,
#   'mub': 0.08,
#   'RHO_Ab': 13.4,
#   'time_lag_asthb': 1.59,
#   'zsb': 0.0,
#   'zl0b': 33.17,
#   'zlb': 0.37,
#   'zbb': 0.0,
#   'temp_cb': 2.1,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 13.63})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_FAC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FAC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FAC_m21ka)
# Out:
# [0.00030058]
# [7.83598622e-10]
# [1.75367139e-05]
# ({'c_slide_initb': 1.16,
#   'c_dis_dab': 0.14,
#   'q_geob': 0.0,
#   'Hb': 29.5,
#   'gamma_sb': 0.38,
#   's_statb': 0.72,
#   'beta1b': 0.16,
#   'beta2b': 0.39,
#   'Pmaxb': 0.26,
#   'mub': 0.0,
#   'RHO_Ab': 2.13,
#   'time_lag_asthb': 0.05,
#   'zsb': 0.19,
#   'zl0b': 3.2,
#   'zlb': 5.95,
#   'zbb': 0.0,
#   'temp_cb': 2.85,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 52.2,
#   'delta_tdab': 0.73},
#  {'c_slide_initb': 4.06,
#   'c_dis_dab': 0.85,
#   'q_geob': 0.12,
#   'Hb': 3.41,
#   'gamma_sb': 1.19,
#   's_statb': 5.56,
#   'beta1b': 1.04,
#   'beta2b': 3.31,
#   'Pmaxb': 1.7,
#   'mub': 0.06,
#   'RHO_Ab': 22.04,
#   'time_lag_asthb': 1.19,
#   'zsb': 0.02,
#   'zl0b': 33.41,
#   'zlb': 2.81,
#   'zbb': 0.0,
#   'temp_cb': 6.75,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 6.67,
#   'delta_tdab': 5.78},
#  {'c_slide_initb': 5.17,
#   'c_dis_dab': 1.23,
#   'q_geob': 1.02,
#   'Hb': 3.63,
#   'gamma_sb': 3.37,
#   's_statb': 6.25,
#   'beta1b': 1.19,
#   'beta2b': 3.15,
#   'Pmaxb': 1.86,
#   'mub': 0.05,
#   'RHO_Ab': 21.0,
#   'time_lag_asthb': 0.9,
#   'zsb': 0.01,
#   'zl0b': 32.75,
#   'zlb': 1.27,
#   'zbb': 0.0,
#   'temp_cb': 6.86,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 3.26,
#   'delta_tdab': 7.03})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_SVC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_SVC_m21ka)
# Out:
# [202741.34308174]
# [202922.57235704]
# ({'c_slide_initb': 7.12,
#   'c_dis_dab': 5.04,
#   'q_geob': 0.22,
#   'Hb': 0.54,
#   'gamma_sb': 0.46,
#   's_statb': 11.51,
#   'beta1b': 2.67,
#   'beta2b': 6.39,
#   'Pmaxb': 4.46,
#   'mub': 0.57,
#   'RHO_Ab': 8.55,
#   'time_lag_asthb': 0.84,
#   'zsb': 0.0,
#   'zl0b': 32.18,
#   'zlb': 2.02,
#   'zbb': 0.0,
#   'temp_cb': 3.32,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 14.1},
#  {'c_slide_initb': 6.48,
#   'c_dis_dab': 4.39,
#   'q_geob': 0.87,
#   'Hb': 3.1,
#   'gamma_sb': 1.07,
#   's_statb': 9.67,
#   'beta1b': 2.24,
#   'beta2b': 5.37,
#   'Pmaxb': 3.74,
#   'mub': 0.48,
#   'RHO_Ab': 9.36,
#   'time_lag_asthb': 0.71,
#   'zsb': 0.02,
#   'zl0b': 31.6,
#   'zlb': 3.39,
#   'zbb': 0.0,
#   'temp_cb': 5.31,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 12.19})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FSVC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FSVC_m21ka)
# Out:
# [813846.02988882]
# [813832.05488749]
# ({'c_slide_initb': 4.23,
#   'c_dis_dab': 3.46,
#   'q_geob': 0.34,
#   'Hb': 0.49,
#   'gamma_sb': 0.64,
#   's_statb': 13.57,
#   'beta1b': 3.92,
#   'beta2b': 5.28,
#   'Pmaxb': 4.81,
#   'mub': 2.12,
#   'RHO_Ab': 5.78,
#   'time_lag_asthb': 0.93,
#   'zsb': 0.0,
#   'zl0b': 29.8,
#   'zlb': 3.17,
#   'zbb': 0.0,
#   'temp_cb': 2.82,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 18.66},
#  {'c_slide_initb': 3.9,
#   'c_dis_dab': 3.42,
#   'q_geob': 1.49,
#   'Hb': 0.48,
#   'gamma_sb': 0.77,
#   's_statb': 13.34,
#   'beta1b': 3.88,
#   'beta2b': 5.05,
#   'Pmaxb': 4.73,
#   'mub': 2.17,
#   'RHO_Ab': 6.95,
#   'time_lag_asthb': 0.9,
#   'zsb': 0.0,
#   'zl0b': 32.2,
#   'zlb': 0.76,
#   'zbb': 0.0,
#   'temp_cb': 1.97,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 17.99})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_SVC_nudged_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_SVC_nudged_m21ka)
# Out:
# [15022.19230206]
# [14849.45461321]
# ({'c_slide_initb': 31.79,
#   'c_dis_dab': 8.87,
#   'q_geob': 0.17,
#   'Hb': 0.62,
#   'gamma_sb': 0.16,
#   's_statb': 14.26,
#   'beta1b': 2.1,
#   'beta2b': 11.99,
#   'Pmaxb': 4.16,
#   'mub': 0.51,
#   'RHO_Ab': 0.95,
#   'time_lag_asthb': 0.33,
#   'zsb': 0.0,
#   'zl0b': 2.4,
#   'zlb': 0.04,
#   'zbb': 0.0,
#   'temp_cb': 4.93,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 16.73},
#  {'c_slide_initb': 32.02,
#   'c_dis_dab': 9.07,
#   'q_geob': 0.77,
#   'Hb': 0.49,
#   'gamma_sb': 0.34,
#   's_statb': 14.5,
#   'beta1b': 2.07,
#   'beta2b': 12.37,
#   'Pmaxb': 4.08,
#   'mub': 0.36,
#   'RHO_Ab': 0.96,
#   'time_lag_asthb': 0.33,
#   'zsb': 0.0,
#   'zl0b': 2.37,
#   'zlb': 0.15,
#   'zbb': 0.0,
#   'temp_cb': 2.89,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 17.23})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_FSVC_nudged_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_FSVC_nudged_m21ka)
# Out:
# [15.68509439]
# [4.53057033e-12]
# ({'c_slide_initb': 18.72,
#   'c_dis_dab': 3.53,
#   'q_geob': 1.09,
#   'Hb': 3.09,
#   'gamma_sb': 0.47,
#   's_statb': 15.91,
#   'beta1b': 3.29,
#   'beta2b': 7.46,
#   'Pmaxb': 5.35,
#   'mub': 2.9,
#   'RHO_Ab': 1.59,
#   'time_lag_asthb': 0.49,
#   'zsb': 0.02,
#   'zl0b': 4.16,
#   'zlb': 0.23,
#   'zbb': 0.0,
#   'temp_cb': 14.57,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 17.13},
#  {'c_slide_initb': 17.95,
#   'c_dis_dab': 3.41,
#   'q_geob': 5.05,
#   'Hb': 1.58,
#   'gamma_sb': 1.69,
#   's_statb': 13.36,
#   'beta1b': 3.14,
#   'beta2b': 5.79,
#   'Pmaxb': 4.99,
#   'mub': 2.43,
#   'RHO_Ab': 2.34,
#   'time_lag_asthb': 0.44,
#   'zsb': 0.01,
#   'zl0b': 8.23,
#   'zlb': 1.35,
#   'zbb': 0.0,
#   'temp_cb': 9.56,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 0.0,
#   'delta_tdab': 18.7})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_BM5_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_BM5_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_BM5_m21ka)
# Out:
# [2115836.17867118]
# [2115770.92117144]
# [2115959.53640306]
# ({'c_slide_initb': 3.16,
#   'c_dis_dab': 2.63,
#   'q_geob': 0.0,
#   'Hb': 28.07,
#   'gamma_sb': 0.24,
#   's_statb': 4.81,
#   'beta1b': 1.0,
#   'beta2b': 2.37,
#   'Pmaxb': 1.59,
#   'mub': 0.01,
#   'RHO_Ab': 3.24,
#   'time_lag_asthb': 0.12,
#   'zsb': 0.2,
#   'zl0b': 6.54,
#   'zlb': 12.4,
#   'zbb': 0.0,
#   'temp_cb': 4.7,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 24.5,
#   'delta_tdab': 4.43},
#  {'c_slide_initb': 4.02,
#   'c_dis_dab': 2.18,
#   'q_geob': 0.17,
#   'Hb': 2.82,
#   'gamma_sb': 0.84,
#   's_statb': 8.97,
#   'beta1b': 1.85,
#   'beta2b': 4.98,
#   'Pmaxb': 2.89,
#   'mub': 0.19,
#   'RHO_Ab': 14.07,
#   'time_lag_asthb': 1.26,
#   'zsb': 0.02,
#   'zl0b': 29.15,
#   'zlb': 2.78,
#   'zbb': 0.0,
#   'temp_cb': 5.62,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 7.46,
#   'delta_tdab': 10.76},
#  {'c_slide_initb': 3.79,
#   'c_dis_dab': 2.02,
#   'q_geob': 0.97,
#   'Hb': 1.68,
#   'gamma_sb': 1.52,
#   's_statb': 8.09,
#   'beta1b': 1.67,
#   'beta2b': 4.49,
#   'Pmaxb': 2.6,
#   'mub': 0.18,
#   'RHO_Ab': 17.24,
#   'time_lag_asthb': 1.15,
#   'zsb': 0.01,
#   'zl0b': 34.11,
#   'zlb': 0.96,
#   'zbb': 0.0,
#   'temp_cb': 4.13,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 5.29,
#   'delta_tdab': 10.11})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_BM5_ZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_BM5_ZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_BM5_ZLC_m21ka)
# Out:
# [2129239.03746724]
# [2129173.63170985]
# [2129362.43208572]
# ({'c_slide_initb': 3.15,
#   'c_dis_dab': 2.62,
#   'q_geob': 0.0,
#   'Hb': 28.02,
#   'gamma_sb': 0.24,
#   's_statb': 4.81,
#   'beta1b': 1.0,
#   'beta2b': 2.37,
#   'Pmaxb': 1.59,
#   'mub': 0.01,
#   'RHO_Ab': 3.26,
#   'time_lag_asthb': 0.12,
#   'zsb': 0.2,
#   'zl0b': 6.58,
#   'zlb': 12.49,
#   'zbb': 0.0,
#   'temp_cb': 4.69,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 24.45,
#   'delta_tdab': 4.42},
#  {'c_slide_initb': 4.01,
#   'c_dis_dab': 2.18,
#   'q_geob': 0.17,
#   'Hb': 2.81,
#   'gamma_sb': 0.83,
#   's_statb': 8.98,
#   'beta1b': 1.85,
#   'beta2b': 4.98,
#   'Pmaxb': 2.89,
#   'mub': 0.19,
#   'RHO_Ab': 14.08,
#   'time_lag_asthb': 1.25,
#   'zsb': 0.02,
#   'zl0b': 29.16,
#   'zlb': 2.78,
#   'zbb': 0.0,
#   'temp_cb': 5.61,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 7.44,
#   'delta_tdab': 10.77},
#  {'c_slide_initb': 3.78,
#   'c_dis_dab': 2.02,
#   'q_geob': 0.97,
#   'Hb': 1.68,
#   'gamma_sb': 1.52,
#   's_statb': 8.11,
#   'beta1b': 1.67,
#   'beta2b': 4.49,
#   'Pmaxb': 2.61,
#   'mub': 0.18,
#   'RHO_Ab': 17.24,
#   'time_lag_asthb': 1.15,
#   'zsb': 0.01,
#   'zl0b': 34.11,
#   'zlb': 0.96,
#   'zbb': 0.0,
#   'temp_cb': 4.12,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 5.28,
#   'delta_tdab': 10.12})

# %%
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m1ka_pkp_init, ds_adj_AC_ZSC_ZLC_m1ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_init, ds_adj_AC_ZSC_ZLC_m11ka), \
non_dim_sensitivities(ds_grl40_bm5_paleo17a_CT4_BH0_m21ka_pkp_init, ds_adj_AC_ZSC_ZLC_m21ka)
# Out:
# [2095485.384074]
# [2095512.09046443]
# [2095541.45844964]
# ({'c_slide_initb': 3.24,
#   'c_dis_dab': 1.54,
#   'q_geob': 0.0,
#   'Hb': 28.17,
#   'gamma_sb': 0.25,
#   's_statb': 6.71,
#   'beta1b': 1.39,
#   'beta2b': 3.07,
#   'Pmaxb': 2.16,
#   'mub': 0.02,
#   'RHO_Ab': 3.59,
#   'time_lag_asthb': 0.17,
#   'zsb': 0.15,
#   'zl0b': 8.26,
#   'zlb': 13.93,
#   'zbb': 0.0,
#   'temp_cb': 4.01,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 17.33,
#   'delta_tdab': 6.02},
#  {'c_slide_initb': 3.06,
#   'c_dis_dab': 2.03,
#   'q_geob': 0.12,
#   'Hb': 1.91,
#   'gamma_sb': 0.77,
#   's_statb': 14.26,
#   'beta1b': 3.18,
#   'beta2b': 6.3,
#   'Pmaxb': 4.74,
#   'mub': 0.26,
#   'RHO_Ab': 9.44,
#   'time_lag_asthb': 1.55,
#   'zsb': 0.01,
#   'zl0b': 26.1,
#   'zlb': 2.33,
#   'zbb': 0.0,
#   'temp_cb': 4.28,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 4.25,
#   'delta_tdab': 15.4},
#  {'c_slide_initb': 2.95,
#   'c_dis_dab': 1.92,
#   'q_geob': 0.73,
#   'Hb': 1.61,
#   'gamma_sb': 1.3,
#   's_statb': 13.11,
#   'beta1b': 2.92,
#   'beta2b': 5.79,
#   'Pmaxb': 4.36,
#   'mub': 0.24,
#   'RHO_Ab': 12.07,
#   'time_lag_asthb': 1.4,
#   'zsb': 0.01,
#   'zl0b': 29.66,
#   'zlb': 1.08,
#   'zbb': 0.0,
#   'temp_cb': 3.4,
#   'vx_cb': 0.0,
#   'vy_cb': 0.0,
#   'vz_cb': 0.0,
#   'age_cb': 3.04,
#   'delta_tdab': 14.41})
