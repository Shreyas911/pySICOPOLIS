# %%
# HPC
import numpy as np
import xarray as xr

# Plotting
import matplotlib.pyplot as plt

# Paths and stuff
import os
import sys

sys.path.append('/home/shreyas/pySICOPOLIS/src')
from pySICOPOLIS import *

# %%
modelPath = '/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/'
ds_11 = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka_ser.nc')
ds_12 = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_ser.nc')

modelPath = '/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups_develop/sico_out/'
ds_21 = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka_ser.nc')
ds_22 = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_ser.nc')

plt.plot(ds_11['t'].data[-551:], (ds_11['V_tot'].data[-551:]-ds_12['V_tot'].data)/ds_11['V_tot'].data[0], color='blue', linestyle='-', label="Spinup vs pickup with BH0 to 0ka with 8.5 CS (ad branch)")
plt.plot(ds_21['t'].data[-551:], (ds_21['V_tot'].data[-551:]-ds_22['V_tot'].data)/ds_21['V_tot'].data[0], color='red', linestyle='--', label="Spinup vs pickup with BH0 to 0ka with 8.5 CS (develop branch)")
plt.legend()

# %%
plt.plot(ds_21['t'].data,(ds_21['V_tot'].data-ds_11['V_tot'].data)/ds_21['V_tot'].data[0], color='blue', linestyle='-', label="Spinup with BH0 to 0ka with 8.5 CS ad branch vs develop branch")
plt.plot(ds_22['t'].data,(ds_22['V_tot'].data-ds_12['V_tot'].data)/ds_22['V_tot'].data[0], color='red', linestyle='--', label="m11ka pickup with BH0 to 0ka with 8.5 CS ad branch vs develop branch")
plt.legend()

# %%
ds_11['V_tot'].data[0], ds_12['V_tot'].data[0], ds_21['V_tot'].data[0], ds_22['V_tot'].data[0]
# Out:
# (2978483900000000.0,
#  3492189000000000.0,
#  2978483900000000.0,
#  3492189000000000.0)

# %%
ds_11['V_tot'].data[-1], ds_12['V_tot'].data[-1], ds_21['V_tot'].data[-1], ds_22['V_tot'].data[-1]
# Out:
# (2967552000000000.0,
#  2967522800000000.0,
#  2967552000000000.0,
#  2967522800000000.0)

# %%
ds_12['V_tot'].data[-1]/ds_11['V_tot'].data[0] - 1
# Out:
# -0.0036800503730773926

# %%
ds_12['V_tot'].data[-1]/ds_11['V_tot'].data[-1] - 1
# Out:
# -9.834766387939453e-06

# %%
modelPath = '/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups_develop/sico_out/'
ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp0006.nc')

modelPath = '/home/shreyas/update_to_develop_sicopolis/sicopolis_spinups/sico_out/'

ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka_ser.nc')
ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka/grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka_ser.nc')
ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka_ser.nc')
ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka_ser.nc')
ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_ser.nc')
ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp_ser.nc')
ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp_ser.nc')
ds_ser_grl40_bm5_spinup02_smooth_100a = xr.open_dataset(modelPath + 'grl40_bm5_spinup02_smooth_100a/grl40_bm5_spinup02_smooth_100a_ser.nc')

ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka0011.nc')
ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka/grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka0011.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka0011.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka/grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka0011.nc')
ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp0006.nc')
ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp0006.nc')
ds_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp = xr.open_dataset(modelPath + 'grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp/grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp0007.nc')
ds_grl40_bm5_spinup02_smooth_100a = xr.open_dataset(modelPath + 'grl40_bm5_spinup02_smooth_100a/grl40_bm5_spinup02_smooth_100a0001.nc')

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["H"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["H"].data))
# Out:
# 0.0

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["age_c"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["age_c"].data))
# Out:
# 0.0

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["zl"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["zl"].data))
# Out:
# 0.0

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["zl0"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["zl0"].data))
# Out:
# 0.0

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["vh_s"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["vh_s"].data))
# Out:
# 0.0

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["vx_s_g"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["vx_s_g"].data))
# Out:
# 0.0

# %%
np.max(np.abs(ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp_develop["vy_s_g"].data - ds_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp["vy_s_g"].data))
# Out:
# 0.0

# %%
ds_ser_grl40_bm5_spinup02_smooth_100a['V_tot'].data[0], \
ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'].data[0], \
ds_ser_grl40_bm5_spinup02_smooth_100a['V_tot'].data[-1], \
ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['V_tot'].data[-1], \
ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['V_tot'].data[-1], \
ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'].data[-1], \
ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['V_tot'].data[-1]
# Out:
# (2978792300000000.0,
#  2978483900000000.0,
#  2977830700000000.0,
#  2967764400000000.0,
#  2969248300000000.0,
#  2967552000000000.0,
#  2967522800000000.0)

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['delta_ts'], color='red', linestyle='-', label="delta_ts")

plt.axvline(x=-120000, color='k', linestyle='--')
plt.axvline(x=-21000, color='k', linestyle='--')
plt.axvline(x=-11000, color='k', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['delta_ts'][-1], color='k', linestyle='--')

plt.axvspan(xmin=-8000, xmax=-5000, color='red', alpha=0.3, label="HCO")
plt.axvspan(xmin=-500, xmax=-150, color='blue', alpha=0.3, label="LIA")

# Add legend on the side
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.title("Total ice volume")

plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['V_tot'], color='blue', linestyle='-', label="Ideal spinup to 0ka with CS 3.5")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['V_tot'], color='green', linestyle='-', label="Ideal spinup to 0ka with D0 with CS 7.25")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['V_tot'], color='purple', linestyle='-', label="Ideal spinup to 0ka with BH0 with D0 with 30.25 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'], color='red', linestyle='-', label="Ideal spinup with BH0 to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['V_tot'], color='red', linestyle='-.', label="Ideal pickup with BH0 -11ka to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['V_tot'], color='orange', linestyle='-.', label="Nudged pickup with BH0 -11ka to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['V_tot'], color='orange', linestyle=':', label="Nudged pickup with BH0 -21ka to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_spinup02_smooth_100a['t'], ds_ser_grl40_bm5_spinup02_smooth_100a['V_tot'], color='black', linestyle='-', label="Smoothed present-day topography using a 100 year run for nudging ")

plt.axvline(x=-120000, color='k', linestyle='--')
plt.axvline(x=-21000, color='k', linestyle='--')
plt.axvline(x=-11000, color='k', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['V_tot'][0], color='blue', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['V_tot'][0], color='green', linestyle=':')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['V_tot'][0], color='purple', linestyle=':')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'][0], color='purple', linestyle='--')

plt.axvspan(xmin=-8000, xmax=-5000, color='red', alpha=0.3, label="HCO")
plt.axvspan(xmin=-500, xmax=-150, color='blue', alpha=0.3, label="LIA")

# Add legend on the side
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.title("Total ice volume")
plt.xlim(-25000,0)
plt.ylim(2.8e15,3.8e15)

plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['V_tot'], color='blue', linestyle='-', label="Ideal spinup to 0ka with CS 3.5")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['V_tot'], color='green', linestyle='-', label="Ideal spinup to 0ka with D0 with CS 7.25")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['V_tot'], color='purple', linestyle='-', label="Ideal spinup to 0ka with BH0 with D0 with 30.25 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'], color='red', linestyle='-', label="Ideal spinup with BH0 to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['V_tot'], color='red', linestyle='-.', label="Ideal pickup with BH0 to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['V_tot'], color='orange', linestyle='-.', label="Nudged pickup with BH0 -11ka to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['V_tot'], color='orange', linestyle=':', label="Nudged pickup with BH0 -21ka to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_spinup02_smooth_100a['t'], ds_ser_grl40_bm5_spinup02_smooth_100a['V_tot'], color='black', linestyle='-', label="Smoothed present-day topography using a 100 year run for nudging ")

plt.axvline(x=-120000, color='k', linestyle='--')
plt.axvline(x=-21000, color='k', linestyle='--')
plt.axvline(x=-11000, color='k', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['V_tot'][0], color='blue', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['V_tot'][0], color='green', linestyle=':')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['V_tot'][0], color='purple', linestyle=':')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'][0], color='purple', linestyle='--')

plt.axvspan(xmin=-8000, xmax=-5000, color='red', alpha=0.3, label="HCO")
plt.axvspan(xmin=-500, xmax=-150, color='blue', alpha=0.3, label="LIA")

# Add legend on the side
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.title("Total ice volume")
plt.xlim(-1000,0)
plt.ylim(2.8e15,3.0e15)

# plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['V_tot'], color='blue', linestyle='-', label="Ideal spinup to 0ka with CS 3.5")
# plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['V_tot'], color='green', linestyle='-', label="Ideal spinup to 0ka with D0 with CS 7.25")
# plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['V_tot'], color='purple', linestyle='-', label="Ideal spinup to 0ka with BH0 with D0 with 30.25 CS")
# plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'], color='red', linestyle='-', label="Ideal spinup with BH0 to 0ka with 8.5 CS")
# plt.plot(ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_CT4_BH0_m11ka_pkp['V_tot'], color='red', linestyle='-.', label="Ideal pickup with BH0 to 0ka with 8.5 CS")
# plt.plot(ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m11ka_pkp['V_tot'], color='orange', linestyle='-.', label="Nudged pickup with BH0 -11ka to 0ka with 8.5 CS")
# plt.plot(ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['t'], ds_ser_grl40_bm5_paleo17a_nudged_CT4_BH0_m21ka_pkp['V_tot'], color='orange', linestyle=':', label="Nudged pickup with BH0 -21ka to 0ka with 8.5 CS")
plt.plot(ds_ser_grl40_bm5_spinup02_smooth_100a['t'], ds_ser_grl40_bm5_spinup02_smooth_100a['V_tot'], color='black', linestyle='-', label="Smoothed present-day topography using a 100 year run for nudging ")

plt.axvline(x=-120000, color='k', linestyle='--')
plt.axvline(x=-21000, color='k', linestyle='--')
plt.axvline(x=-11000, color='k', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['V_tot'][0], color='blue', linestyle='--')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['V_tot'][0], color='green', linestyle=':')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['V_tot'][0], color='purple', linestyle=':')
plt.axhline(y=ds_ser_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['V_tot'][0], color='purple', linestyle='--')

plt.axvspan(xmin=-8000, xmax=-5000, color='red', alpha=0.3, label="HCO")
plt.axvspan(xmin=-500, xmax=-150, color='blue', alpha=0.3, label="LIA")

# Add legend on the side
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.tight_layout()

# %%
n_rows, n_cols = 2, 2
aspect_ratio = len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x'])/len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.5)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

for axis in ax.flatten():
    axis.set_box_aspect(1/aspect_ratio)

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H'],
                         cmap = 'jet', vmin = 0, vmax = 3000, nbins = 20, fig = fig, ax = ax[0,0])
ax[0,0].set_title('CS 3.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['H'],
                         cmap = 'jet', vmin = 0, vmax = 3000, nbins = 20, fig = fig, ax = ax[0,1])
ax[0,1].set_title('D0 and CS 7.25')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['H'],
                         cmap = 'jet', vmin = 0, vmax = 3000, nbins = 20, fig = fig, ax = ax[1,0])
ax[1,0].set_title('BH0 and CS 8.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['H'],
                         cmap = 'jet', vmin = 0, vmax = 3000, nbins = 20, fig = fig, ax = ax[1,1])
ax[1,1].set_title('BH0 and D0 and CS 30.25')

fig.suptitle('Ice sheet thickness 40 kms')
plt.tight_layout()

# %%
n_rows, n_cols = 2, 2
aspect_ratio = len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x'])/len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.5)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H']-ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H'],
                         cmap = 'RdBu_r', vmin = -500, vmax = 500, nbins = 20, fig = fig, ax = ax[0,0])
ax[0,0].set_title('CS 3.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['H']-ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H'],
                         cmap = 'RdBu_r', vmin = -500, vmax = 500, nbins = 20, fig = fig, ax = ax[0,1])
ax[0,1].set_title('D0 and CS 7.25')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['H']-ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H'],
                         cmap = 'RdBu_r', vmin = -500, vmax = 500, nbins = 20, fig = fig, ax = ax[1,0])
ax[1,0].set_title('BH0 and CS 8.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['H']-ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H'],
                         cmap = 'RdBu_r', vmin = -500, vmax = 500, nbins = 20, fig = fig, ax = ax[1,1])
ax[1,1].set_title('BH0 and D0 and CS 30.25')

fig.suptitle('Ice sheet thickness 40 kms deviation from CS 3.5')
plt.tight_layout()

# %%
n_rows, n_cols = 2, 2
aspect_ratio = len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x'])/len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.5)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

z_index = 70

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[0,0])
ax[0,0].set_title('CS 3.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[0,1])
ax[0,1].set_title('D0 and CS 7.25')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[1,0])
ax[1,0].set_title('BH0 and CS 8.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[1,1])
ax[1,1].set_title('BH0 and D0 and CS 30.25')

fig.suptitle(f'Age at z_index {z_index}')
plt.tight_layout()

# %%
n_rows, n_cols = 2, 2
aspect_ratio = len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x'])/len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.5)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

z_index = 50

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[0,0])
ax[0,0].set_title('CS 3.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[0,1])
ax[0,1].set_title('D0 and CS 7.25')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[1,0])
ax[1,0].set_title('BH0 and CS 8.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[1,1])
ax[1,1].set_title('BH0 and D0 and CS 30.25')

fig.suptitle(f'Age at z_index {z_index}')
plt.tight_layout()

# %%
n_rows, n_cols = 2, 2
aspect_ratio = len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x'])/len(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y'])
subplot_width = 4
subplot_height = subplot_width / aspect_ratio
plt.rcParams["figure.figsize"] = ((n_cols+0.5)*subplot_width, n_rows*subplot_height)
fig, ax = plt.subplots(n_rows, n_cols)

z_index = 30

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_3point5CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[0,0])
ax[0,0].set_title('CS 3.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_D0_7point25CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[0,1])
ax[0,1].set_title('D0 and CS 7.25')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_BH0_8point5CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[1,0])
ax[1,0].set_title('BH0 and CS 8.5')

fancyPlotter.plot_normal(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['x']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['y']/1000.0, 
                         ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['age_c'][z_index]*(ds_grl40_bm5_paleo17a_CT4_BH0_D0_30point25CS_spinup_0ka['H']>=1500),
                         cmap = 'jet', vmin = 0, vmax = 11000, nbins = 100, fig = fig, ax = ax[1,1])
ax[1,1].set_title('BH0 and D0 and CS 30.25')

fig.suptitle(f'Age at z_index {z_index}')
plt.tight_layout()
